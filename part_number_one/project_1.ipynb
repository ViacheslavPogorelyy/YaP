# %% [markdown]
# ## Описание проекта
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ## Инструкция по выполнению
#
# ### Шаг 1. Откройте таблицу и изучите общую информацию о данных
#
# ### Шаг 2. Предобработка данных
# * определите и заполните пропущенные значения:
# * опишите, какие пропущенные значения вы обнаружили;
# * приведите возможные причины появления пропусков в данных;
# * объясните, по какому принципу заполнены пропуски;
# * замените вещественный тип данных на целочисленный:
# * поясните, как выбирали метод для изменения типа данных;
# * удалите дубликаты:
# * поясните, как выбирали метод для поиска и удаления дубликатов в данных;
# * приведите возможные причины появления дубликатов;
# * выделите леммы в значениях столбца с целями получения кредита:
# * опишите, как вы проводили лемматизацию целей кредита;
# * категоризируйте данные: перечислите, какие «словари» вы выделили для этого набора данных, и объясните, почему.
#
# В данных могут встречаться артефакты — значения, которые не отражают действительность. Например, отрицательное количество дней трудового стажа. Для реальных данных — это нормально. Нужно описать возможные причины появления таких данных и обработать их.
#
# ### Шаг 3. Ответьте на вопросы
# * Есть ли зависимость между наличием детей и возвратом кредита в срок?
# * Есть ли зависимость между семейным положением и возвратом кредита в срок?
# * Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# * Как разные цели кредита влияют на его возврат в срок?
#
# Ответы сопроводите интерпретацией — поясните, о чём именно говорит полученный вами результат.
#
# ### Шаг 4. Напишите общий вывод

# %% [markdown]
# #### Описание данных
# 1. `children` — количество детей в семье
# 2. `days_employed` — общий трудовой стаж в днях
# 3. `dob_years` — возраст клиента в годах
# 4.  `education` — уровень образования клиента
# 5.  `education_id` — идентификатор уровня образования
# 6. `family_status` — семейное положение
# 7. `family_status_id` — идентификатор семейного положения
# 8. `gender` — пол клиента
# 9. `income_type` — тип занятости
# 10. `debt` — имел ли задолженность по возврату кредитов
# 11. `total_income` — ежемесячный доход
# 12. `purpose` — цель получения кредита

# %% [markdown]
# ### Шаг 1. Откройте таблицу и изучите общую информацию о данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pymystem3 import Mystem
from collections import Counter

# %%
df = pd.read_csv('data_b.csv')

# %%
df
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1   -8437.673028         42    высшее             0
# 1             1   -4024.803754         36   среднее             1
# 2             0   -5623.422610         33   Среднее             1
# 3             3   -4124.747207         32   среднее             1
# 4             0  340266.072047         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1   -4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1   -2113.346888         38   среднее             1
# 21523         3   -3112.481705         38   среднее             1
# 21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21520  224791.862382             операции с жильем
# 21521  155999.806512          сделка с автомобилем
# 21522   89672.561153                  недвижимость
# 21523  244093.050500  на покупку своего автомобиля
# 21524   82047.418899         на покупку автомобиля
#
# [21525 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Вывод:
#
# В результате знакомства с данными удалось обнаружить, что в двух столбцах имеются пропущенные значения, которые необходимо проработать.

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# Пропущенные значения у нас есть в колонках `days_employed` и `total_income`. Посчитаем сколько их всех и установим процент пропусков.

# %%
df['days_employed'].isna().agg([sum, 'mean'])
# Out:
# sum     2174.000000
# mean       0.100999
# Name: days_employed, dtype: float64

# %%
df['total_income'].isna().agg([sum, 'mean'])
# Out:
# sum     2174.000000
# mean       0.100999
# Name: total_income, dtype: float64

# %% [markdown]
# Как мы видим, количество пропусков вместе с их долей в во всем датафрейме совпадает. Теперь взглянем на датасет только с пропусками и попытаемся найти общую закономерность

# %%
nan = df[df['days_employed'].isna() == True]

# %%
nan.sample(10)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 9183          0            NaN         55   среднее             1
# 15322         1            NaN         43    высшее             0
# 15506         0            NaN         50   среднее             1
# 6416          1            NaN         41   среднее             1
# 13816         0            NaN         25   среднее             1
# 11383         1            NaN         45    высшее             0
# 360           0            NaN         27   среднее             1
# 3539          0            NaN         40   среднее             1
# 19602         1            NaN         39   среднее             1
# 10980         2            NaN         30   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 9183   Не женат / не замужем                 4      M    компаньон     0
# 15322        женат / замужем                 0      F    компаньон     0
# 15506        женат / замужем                 0      F    пенсионер     0
# 6416         женат / замужем                 0      F    компаньон     0
# 13816  Не женат / не замужем                 4      F  госслужащий     0
# 11383        женат / замужем                 0      M    компаньон     0
# 360          женат / замужем                 0      M    компаньон     0
# 3539         женат / замужем                 0      M    компаньон     0
# 19602        женат / замужем                 0      F    компаньон     0
# 10980        женат / замужем                 0      F    сотрудник     0
#
#        total_income                                 purpose
# 9183            NaN                 покупка жилья для семьи
# 15322           NaN   операции с коммерческой недвижимостью
# 15506           NaN                 покупка жилья для семьи
# 6416            NaN  строительство собственной недвижимости
# 13816           NaN                                   жилье
# 11383           NaN           получение высшего образования
# 360             NaN                 покупка жилья для сдачи
# 3539            NaN                           покупка жилья
# 19602           NaN              покупка жилой недвижимости
# 10980           NaN                      высшее образование

# %%
pd.cut(df['dob_years'], 5).value_counts()
# Out:
# (30.0, 45.0]      8504
# (45.0, 60.0]      7057
# (15.0, 30.0]      3723
# (60.0, 75.0]      2140
# (-0.075, 15.0]     101
# Name: dob_years, dtype: int64

# %% [markdown]
# Как мы видим, у нас есть клиенты, у которых в графе возраст есть отрицательные значения и совсем маленькие. Логично, что тут произошла какая-то ошибка при выкачке данных. Поскольку этих данных совсем мало, то их удаление не повлияет на результаты анализа.

# %%
df = df[df['dob_years'] > 15].reset_index()

# %%
df
# Out:
#        index  children  days_employed  dob_years education  education_id  \
# 0          0         1   -8437.673028         42    высшее             0
# 1          1         1   -4024.803754         36   среднее             1
# 2          2         0   -5623.422610         33   Среднее             1
# 3          3         3   -4124.747207         32   среднее             1
# 4          4         0  340266.072047         53   среднее             1
# ...      ...       ...            ...        ...       ...           ...
# 21419  21520         1   -4529.316663         43   среднее             1
# 21420  21521         0  343937.404131         67   среднее             1
# 21421  21522         1   -2113.346888         38   среднее             1
# 21422  21523         3   -3112.481705         38   среднее             1
# 21423  21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21419  гражданский брак                 1      F   компаньон     0
# 21420   женат / замужем                 0      F   пенсионер     0
# 21421  гражданский брак                 1      M   сотрудник     1
# 21422   женат / замужем                 0      M   сотрудник     1
# 21423   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21419  224791.862382             операции с жильем
# 21420  155999.806512          сделка с автомобилем
# 21421   89672.561153                  недвижимость
# 21422  244093.050500  на покупку своего автомобиля
# 21423   82047.418899         на покупку автомобиля
#
# [21424 rows x 13 columns]

# %% [markdown]
# В целом, какой-то общей закономерности пропусков не удалось обнаружить

# %%
def category(age):
    if age <= 30:
        return 'молодые'
    if age > 30 and age <= 45:
        return 'взрослые'
    if age > 45 and age <= 60:
        return 'пожилые'
    return 'пенсионеры'

# %%
df['category'] = df['dob_years'].apply(category)

# %%
df
# Out:
#        index  children  days_employed  dob_years education  education_id  \
# 0          0         1   -8437.673028         42    высшее             0
# 1          1         1   -4024.803754         36   среднее             1
# 2          2         0   -5623.422610         33   Среднее             1
# 3          3         3   -4124.747207         32   среднее             1
# 4          4         0  340266.072047         53   среднее             1
# ...      ...       ...            ...        ...       ...           ...
# 21419  21520         1   -4529.316663         43   среднее             1
# 21420  21521         0  343937.404131         67   среднее             1
# 21421  21522         1   -2113.346888         38   среднее             1
# 21422  21523         3   -3112.481705         38   среднее             1
# 21423  21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21419  гражданский брак                 1      F   компаньон     0
# 21420   женат / замужем                 0      F   пенсионер     0
# 21421  гражданский брак                 1      M   сотрудник     1
# 21422   женат / замужем                 0      M   сотрудник     1
# 21423   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose    category
# 0      253875.639453                 покупка жилья    взрослые
# 1      112080.014102       приобретение автомобиля    взрослые
# 2      145885.952297                 покупка жилья    взрослые
# 3      267628.550329    дополнительное образование    взрослые
# 4      158616.077870               сыграть свадьбу     пожилые
# ...              ...                           ...         ...
# 21419  224791.862382             операции с жильем    взрослые
# 21420  155999.806512          сделка с автомобилем  пенсионеры
# 21421   89672.561153                  недвижимость    взрослые
# 21422  244093.050500  на покупку своего автомобиля    взрослые
# 21423   82047.418899         на покупку автомобиля    взрослые
#
# [21424 rows x 14 columns]

# %% [markdown]
# Посмотрим для каждой возрастной категории среднее значение по гендерным признакам.

# %%
gender_category = df.pivot_table(index = 'category', columns = 'gender', values = 'total_income', aggfunc = 'median')

# %%
gender_category
# Out:
# gender                  F              M            XNA
# category
# взрослые    140315.766455  176410.847993            NaN
# молодые     130187.630873  162513.291433  203905.157261
# пенсионеры  121084.030049  131382.818886            NaN
# пожилые     133412.900442  166523.462873            NaN

# %% [markdown]
# У нас появилось какое-то лишнее значение в графе `gender`, попробуем глянуть сколькор их.

# %%
df['gender'].value_counts()
# Out:
# F      14164
# M       7259
# XNA        1
# Name: gender, dtype: int64

# %% [markdown]
# Можно сразу избавиться от XNA, чтобы это значение не мешало в дальнейшем.

# %%
df = df.query('gender != "XNA"').reset_index()

# %%
df.sample(5)
# Out:
#        level_0  index  children  days_employed  dob_years education  \
# 16538    16539  16623         0  341315.519351         58   среднее
# 8721      8721   8762         0    -138.523364         59    высшее
# 11544    11545  11602         0    -728.541237         45    высшее
# 20604    20605  20704         2    -610.011626         27   среднее
# 20554    20555  20654         1   -1812.084854         37   среднее
#
#        education_id     family_status  family_status_id gender income_type  \
# 16538             1   женат / замужем                 0      F   пенсионер
# 8721              0  гражданский брак                 1      F   компаньон
# 11544             0   женат / замужем                 0      F   компаньон
# 20604             1   женат / замужем                 0      F   сотрудник
# 20554             1  гражданский брак                 1      F   сотрудник
#
#        debt   total_income                                 purpose  category
# 16538     0  107893.288611  строительство собственной недвижимости   пожилые
# 8721      0  293672.584812                   на проведение свадьбы   пожилые
# 11544     0  432530.632110  строительство собственной недвижимости  взрослые
# 20604     0  151216.458750   операции с коммерческой недвижимостью   молодые
# 20554     0  240127.623122       покупка коммерческой недвижимости  взрослые

# %% [markdown]
# У нас появились лишние столбцы с индексами, которые не несут никакого смысла. Все это можно удлать.

# %%
df = df.drop(['level_0', 'index'], axis = 1)

# %%
woman_adult = gender_category['F'][0]
woman_young = gender_category['F'][1]
woman_pensioner = gender_category['F'][2]
woman_old = gender_category['F'][3]
man_adult = gender_category['M'][0]
man_young = gender_category['M'][1]
man_pensioner = gender_category['M'][2]
man_old = gender_category['M'][3]

# %%
t = df['gender']
k = df['category']
g = []
for i in range(len(k)):
    if t[i] == 'F'and k[i] == 'взрослые':
        g.append(woman_adult)
    if t[i] == 'F'and k[i] == 'молодые':
        g.append(woman_young)
    if t[i] == 'F'and k[i] == 'пенсионеры':
        g.append(woman_pensioner)
    if t[i] == 'F'and k[i] == 'пожилые':
        g.append(woman_old)
    if t[i] == 'M' and k[i] == 'взрослые':
        g.append(man_adult)
    if t[i] == 'M'and k[i] == 'молодые':
        g.append(man_young)
    if t[i] == 'M'and k[i] == 'пенсионеры':
        g.append(man_pensioner)
    if t[i] == 'M'and k[i] == 'пожилые':
        g.append(man_old)

# %%
df['inc_cat'] = pd.Series(g)

# %%
df.sample(10)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 9246          0   -1086.378928         43   СРЕДНЕЕ             1
# 9348          1    -968.325659         25   среднее             1
# 15048         0   -1765.469604         43   среднее             1
# 13263         1    -585.669288         31   среднее             1
# 1403          1    -482.080149         57   среднее             1
# 11964         0   -3426.860671         40    ВЫСШЕЕ             0
# 8349          1  343422.232324         46    высшее             0
# 6751          1   -8135.135462         45   среднее             1
# 20023         0   -1733.626977         27   Среднее             1
# 3339          0    -281.843354         27   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 9246         женат / замужем                 0      M    компаньон     0
# 9348         женат / замужем                 0      F    сотрудник     0
# 15048  Не женат / не замужем                 4      M    сотрудник     0
# 13263        женат / замужем                 0      F  госслужащий     0
# 1403        гражданский брак                 1      M    сотрудник     0
# 11964       гражданский брак                 1      M    сотрудник     0
# 8349         женат / замужем                 0      F    пенсионер     0
# 6751   Не женат / не замужем                 4      F    сотрудник     0
# 20023       гражданский брак                 1      M    сотрудник     0
# 3339         женат / замужем                 0      F    сотрудник     0
#
#         total_income                                 purpose  category  \
# 9246   140764.504642  строительство собственной недвижимости  взрослые
# 9348   188917.721102                              автомобиль   молодые
# 15048  116668.689955                 покупка жилья для семьи  взрослые
# 13263  130671.949813              дополнительное образование  взрослые
# 1403   183284.431185                         сыграть свадьбу   пожилые
# 11964  174733.996899                                 свадьба  взрослые
# 8349   176809.160773                   на покупку автомобиля   пожилые
# 6751    82978.362990                    сделка с автомобилем  взрослые
# 20023   99939.720476                         сыграть свадьбу   молодые
# 3339   143683.031358   операции с коммерческой недвижимостью   молодые
#
#              inc_cat
# 9246   176410.847993
# 9348   130187.630873
# 15048  176410.847993
# 13263  140315.766455
# 1403   166523.462873
# 11964  176410.847993
# 8349   133412.900442
# 6751   140315.766455
# 20023  162513.291433
# 3339   130187.630873

# %%
df['total_income'] = df['total_income'].fillna(df['inc_cat'])

# %% [markdown]
# Переведем отрицательные знацения стажа в абсолютные

# %%
df['days_employed'] = abs(df['days_employed'])

# %% [markdown]
# Считаю, что здесь можно воспользоваться такой же логикой замены пропусков какая была при замене `total_income`

# %%
for_days_emp = df.pivot_table(index = 'category', columns = 'gender', values = 'days_employed', aggfunc = 'median')

# %%
for_days_emp
# Out:
# gender                  F              M
# category
# взрослые      1831.729975    1606.607248
# молодые       1097.531171     981.593723
# пенсионеры  358166.492161  347977.727190
# пожилые       4851.384110    2412.732199

# %%
woman_adult_days = for_days_emp['F'][0]
woman_young_days = for_days_emp['F'][1]
woman_pensioner_days = for_days_emp['F'][2]
woman_old_days = for_days_emp['F'][3]
man_adult_days = for_days_emp['M'][0]
man_young_days = for_days_emp['M'][1]
man_pensioner_days = for_days_emp['M'][2]
man_old_days = for_days_emp['M'][3]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21423 entries, 0 to 21422
# Data columns (total 14 columns):
# children            21423 non-null int64
# days_employed       19259 non-null float64
# dob_years           21423 non-null int64
# education           21423 non-null object
# education_id        21423 non-null int64
# family_status       21423 non-null object
# family_status_id    21423 non-null int64
# gender              21423 non-null object
# income_type         21423 non-null object
# debt                21423 non-null int64
# total_income        21423 non-null float64
# purpose             21423 non-null object
# category            21423 non-null object
# inc_cat             21423 non-null float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 2.3+ MB

# %%
c = df['gender']
v = df['category']
h = []
for i in range(len(v)):
    if c[i] == 'F'and v[i] == 'взрослые':
        h.append(woman_adult_days)
    if c[i] == 'F'and v[i] == 'молодые':
        h.append(woman_young_days)
    if c[i] == 'F'and v[i] == 'пенсионеры':
        h.append(woman_pensioner_days)
    if c[i] == 'F'and v[i] == 'пожилые':
        h.append(woman_old_days)
    if c[i] == 'M' and v[i] == 'взрослые':
        h.append(man_adult_days)
    if c[i] == 'M'and v[i] == 'молодые':
        h.append(man_young_days)
    if c[i] == 'M'and v[i] == 'пенсионеры':
        h.append(man_pensioner_days)
    if c[i] == 'M'and v[i] == 'пожилые':
        h.append(man_old_days)

# %%
len(h)
# Out:
# 21423

# %%
df['days'] = pd.Series(h)
df.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0     926.185831         27    высшее             0
# 6         0    2879.202052         43    высшее             0
# 7         0     152.779569         50   СРЕДНЕЕ             1
# 8         2    6929.865299         35    ВЫСШЕЕ             0
# 9         0    2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
# 5  гражданский брак                 1      M   компаньон     0  255763.565419
# 6   женат / замужем                 0      F   компаньон     0  240525.971920
# 7   женат / замужем                 0      M   сотрудник     0  135823.934197
# 8  гражданский брак                 1      F   сотрудник     0   95856.832424
# 9   женат / замужем                 0      M   сотрудник     0  144425.938277
#
#                       purpose  category        inc_cat         days
# 0               покупка жилья  взрослые  140315.766455  1831.729975
# 1     приобретение автомобиля  взрослые  140315.766455  1831.729975
# 2               покупка жилья  взрослые  176410.847993  1606.607248
# 3  дополнительное образование  взрослые  176410.847993  1606.607248
# 4             сыграть свадьбу   пожилые  133412.900442  4851.384110
# 5               покупка жилья   молодые  162513.291433   981.593723
# 6           операции с жильем  взрослые  140315.766455  1831.729975
# 7                 образование   пожилые  166523.462873  2412.732199
# 8       на проведение свадьбы  взрослые  140315.766455  1831.729975
# 9     покупка жилья для семьи  взрослые  176410.847993  1606.607248

# %%
df['days_employed'] = df['days_employed'].fillna(df['days'])

# %%
df.sample(10)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 14685         2    1328.138947         31               высшее             0
# 14166         0  358166.492161         61              среднее             1
# 16302         0     758.636052         22  неоконченное высшее             2
# 2690          0  374433.906699         62            начальное             3
# 10799         0    3616.680375         46               высшее             0
# 13710         2    1326.241881         38              среднее             1
# 3521          0    1606.607248         40              среднее             1
# 1103          1     208.945004         33               высшее             0
# 17437         2     264.120544         35              среднее             1
# 9780          0     183.570863         25  неоконченное высшее             2
#
#                family_status  family_status_id gender  income_type  debt  \
# 14685        женат / замужем                 0      F    компаньон     0
# 14166       гражданский брак                 1      F    пенсионер     0
# 16302       гражданский брак                 1      F    компаньон     0
# 2690   Не женат / не замужем                 4      F    пенсионер     0
# 10799  Не женат / не замужем                 4      F    компаньон     1
# 13710        женат / замужем                 0      F    компаньон     0
# 3521         женат / замужем                 0      M    компаньон     0
# 1103               в разводе                 3      F    сотрудник     0
# 17437        женат / замужем                 0      F    сотрудник     0
# 9780   Не женат / не замужем                 4      M  госслужащий     0
#
#         total_income                                 purpose    category  \
# 14685  228491.456797  строительство собственной недвижимости    взрослые
# 14166  121084.030049                         сыграть свадьбу  пенсионеры
# 16302  128609.886033                              автомобили     молодые
# 2690    66151.396420                    покупка своего жилья  пенсионеры
# 10799  257107.782958              дополнительное образование     пожилые
# 13710  136758.451728                 покупка жилья для семьи    взрослые
# 3521   176410.847993                           покупка жилья    взрослые
# 1103   219243.051899                 приобретение автомобиля    взрослые
# 17437  213702.819101   операции с коммерческой недвижимостью    взрослые
# 9780   137395.348010                             образование     молодые
#
#              inc_cat           days
# 14685  140315.766455    1831.729975
# 14166  121084.030049  358166.492161
# 16302  130187.630873    1097.531171
# 2690   121084.030049  358166.492161
# 10799  133412.900442    4851.384110
# 13710  140315.766455    1831.729975
# 3521   176410.847993    1606.607248
# 1103   140315.766455    1831.729975
# 17437  140315.766455    1831.729975
# 9780   162513.291433     981.593723

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21423 entries, 0 to 21422
# Data columns (total 15 columns):
# children            21423 non-null int64
# days_employed       21423 non-null float64
# dob_years           21423 non-null int64
# education           21423 non-null object
# education_id        21423 non-null int64
# family_status       21423 non-null object
# family_status_id    21423 non-null int64
# gender              21423 non-null object
# income_type         21423 non-null object
# debt                21423 non-null int64
# total_income        21423 non-null float64
# purpose             21423 non-null object
# category            21423 non-null object
# inc_cat             21423 non-null float64
# days                21423 non-null float64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 2.5+ MB

# %%
df.duplicated().sum()
# Out:
# 54

# %%
df = df.drop_duplicates(keep='first')

# %%
df.sample(5)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 997           0    8810.048966         54   среднее             1
# 18194         0    5160.625652         49   среднее             1
# 12266         1    1606.607248         31   среднее             1
# 18527         0    1896.866606         43    высшее             0
# 17672         0     515.324817         41   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 997     женат / замужем                 0      F   сотрудник     0
# 18194    вдовец / вдова                 2      F   сотрудник     0
# 12266   женат / замужем                 0      M   сотрудник     1
# 18527   женат / замужем                 0      F   компаньон     0
# 17672  гражданский брак                 1      F   сотрудник     1
#
#         total_income                          purpose  category  \
# 997    102220.599728  операции со своей недвижимостью   пожилые
# 18194  183066.967923               высшее образование   пожилые
# 12266  176410.847993                операции с жильем  взрослые
# 18527  164762.705751                     ремонт жилью  взрослые
# 17672   88866.867449           профильное образование  взрослые
#
#              inc_cat         days
# 997    133412.900442  4851.384110
# 18194  133412.900442  4851.384110
# 12266  176410.847993  1606.607248
# 18527  140315.766455  1831.729975
# 17672  140315.766455  1831.729975

# %% [markdown]
# Уберем лишние столбцы, которые нам больше не понадобятся.

# %%
df = df.drop(['inc_cat', 'days'], axis = 1)

# %% [markdown]
# Теперь округлим и заменим тип данных в столбцах `days_employed` и `total_income` для дальнейшего удоства.

# %%
df['days_employed'] = round(df['days_employed'], 0)
df['days_employed'] = df['days_employed'].astype(int)
df['total_income'] = round(df['total_income'], 0)
df['total_income'] = df['total_income'].astype(int)

# %%
df.dtypes
# Out:
# children             int64
# days_employed        int32
# dob_years            int64
# education           object
# education_id         int64
# family_status       object
# family_status_id     int64
# gender              object
# income_type         object
# debt                 int64
# total_income         int32
# purpose             object
# category            object
# dtype: object

# %%
df
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1           8438         42    высшее             0
# 1             1           4025         36   среднее             1
# 2             0           5623         33   Среднее             1
# 3             3           4125         32   среднее             1
# 4             0         340266         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21418         1           4529         43   среднее             1
# 21419         0         343937         67   среднее             1
# 21420         1           2113         38   среднее             1
# 21421         3           3112         38   среднее             1
# 21422         2           1985         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21418  гражданский брак                 1      F   компаньон     0
# 21419   женат / замужем                 0      F   пенсионер     0
# 21420  гражданский брак                 1      M   сотрудник     1
# 21421   женат / замужем                 0      M   сотрудник     1
# 21422   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose    category
# 0            253876                 покупка жилья    взрослые
# 1            112080       приобретение автомобиля    взрослые
# 2            145886                 покупка жилья    взрослые
# 3            267629    дополнительное образование    взрослые
# 4            158616               сыграть свадьбу     пожилые
# ...             ...                           ...         ...
# 21418        224792             операции с жильем    взрослые
# 21419        156000          сделка с автомобилем  пенсионеры
# 21420         89673                  недвижимость    взрослые
# 21421        244093  на покупку своего автомобиля    взрослые
# 21422         82047         на покупку автомобиля    взрослые
#
# [21369 rows x 13 columns]

# %% [markdown]
# Для дальнейшего анализа нам необходимо определить леммы, чтобы мы смогли отфильтровать клиентов по причинам займа.

# %%
unique = df['purpose'].unique()

# %%
from pymystem3 import Mystem
m = Mystem()
from collections import Counter

# %%
key = df['purpose']
lem = []
for i in key:
    result = ''.join(m.lemmatize(i)).strip()
    lem.append(result)

#df1 = pd.DataFrame(data=lem, columns=['lemmas'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-524-fbb4d97ecf8e> in <module>
#       2 lem = []
#       3 for i in key:
# ----> 4     result = ''.join(m.lemmatize(i)).strip()
#       5     lem.append(result)
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     311             self._procin.write(_NL)
#     312
# --> 313             out, _ = self._proc.communicate()
#     314             self._proc = None
#     315             try:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in communicate(self, input, timeout)
#     937
#     938             try:
# --> 939                 stdout, stderr = self._communicate(input, endtime, timeout)
#     940             except KeyboardInterrupt:
#     941                 # https://bugs.python.org/issue25942
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1265             # calls communicate again.
#    1266             if self.stdout is not None:
# -> 1267                 self.stdout_thread.join(self._remaining_time(endtime))
#    1268                 if self.stdout_thread.is_alive():
#    1269                     raise TimeoutExpired(self.args, orig_timeout)
#
# C:\ProgramData\Anaconda3\lib\threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# C:\ProgramData\Anaconda3\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

text = df['purpose']
res = []

def lemmatize(text):
    words = text # разбиваем текст на слова
    for word in words:
        p = morph.parse(word)[0]
        res.append(p.normal_form)

    return res

print(lemmatize(text))
# Out:
# ['покупка жильё', 'приобретение автомобиль', 'покупка жильё', 'дополнительное образование', 'сыграть свадьба', 'покупка жильё', 'операции с жилие', 'образование', 'на проведение свадьба', 'покупка жилья для семья', 'покупка недвижимость', 'покупка коммерческой недвижимость', 'сыграть свадьба', 'приобретение автомобиль', 'покупка жилой недвижимость', 'строительство собственной недвижимость', 'недвижимость', 'строительство недвижимость', 'на покупку подержанного автомобиль', 'на покупку своего автомобиль', 'недвижимость', 'приобретение автомобиль', 'на покупку подержанного автомобиль', 'сыграть свадьба', 'операции с коммерческой недвижимость', 'покупка недвижимость', 'образование', 'строительство собственной недвижимость', 'строительство собственной недвижимость', 'строительство жилой недвижимость', 'операции с коммерческой недвижимость', 'жильё', 'на проведение свадьба', 'покупка жильё', 'операции со своей недвижимость', 'на проведение свадьба', 'автомобиль', 'приобретение автомобиль', 'образование', 'заняться образование', 'покупка недвижимость', 'сделка с подержанным автомобиль', 'получение образование', 'приобретение автомобиль', 'на покупку своего автомобиль', 'заняться образование', 'сделка с подержанным автомобиль', 'на проведение свадьба', 'строительство собственной недвижимость', 'автомобиль', 'автомобиль', 'свадьба', 'получение дополнительного образование', 'покупка своего жильё', 'автомобиль', 'сыграть свадьба', 'образование', 'образование', 'недвижимость', 'операции с недвижимость', 'заняться образование', 'покупка недвижимость', 'получение высшего образование', 'операции с жилие', 'сделка с подержанным автомобиль', 'операции с коммерческой недвижимость', 'заняться образование', 'покупка жилья для семья', 'операции с коммерческой недвижимость', 'покупка своего жильё', 'покупка коммерческой недвижимость', 'автомобиль', 'операции с коммерческой недвижимость', 'заняться образование', 'покупка жилья для семья', 'операции с недвижимость', 'на покупку подержанного автомобиль', 'свой автомобиль', 'сделка с автомобиль', 'автомобиль', 'сделка с автомобиль', 'профильное образование', 'жильё', 'жильё', 'операции со своей недвижимость', 'высшее образование', 'свадьба', 'покупка жилья для сдача', 'на проведение свадьба', 'сделка с подержанным автомобиль', 'операции с жилие', 'покупка недвижимость', 'сыграть свадьба', 'сделка с автомобиль', 'на проведение свадьба', 'автомобиль', 'покупка жилой недвижимость', 'профильное образование', 'покупка жилья для сдача', 'операции с недвижимость', 'на покупку своего автомобиль', 'на покупку подержанного автомобиль', 'строительство недвижимость', 'покупка жилья для сдача', 'строительство собственной недвижимость', 'образование', 'строительство собственной недвижимость', 'сделка с подержанным автомобиль', 'образование', 'покупка жильё', 'недвижимость', 'недвижимость', 'образование', 'операции со своей недвижимость', 'операции с коммерческой недвижимость', 'покупка жилой недвижимость', 'на покупку автомобиль', 'на проведение свадьба', 'покупка коммерческой недвижимость', 'высшее образование', 'автомобиль', 'автомобиль', 'покупка жилья для сдача', 'операции с коммерческой недвижимость', 'свадьба', 'строительство собственной недвижимость', 'строительство жилой недвижимость', 'сделка с автомобиль', 'автомобиль', 'операции со своей недвижимость', 'получение дополнительного образование', 'автомобиль', 'образование', 'покупка жилой недвижимость', 'жильё', 'операции со своей недвижимость', 'сыграть свадьба', 'покупка своего жильё', 'ремонт жильё', 'покупка коммерческой недвижимость', 'свадьба', 'сделка с подержанным автомобиль', 'строительство собственной недвижимость', 'свой автомобиль', 'строительство недвижимость', 'покупка жильё', 'операции с недвижимость', 'на покупку своего автомобиль', 'сыграть свадьба', 'сыграть свадьба', 'покупка своего жильё', 'жильё', 'операции с коммерческой недвижимость', 'дополнительное образование', 'получение дополнительного образование', 'сделка с автомобиль', 'образо ...

# %%
df['lemma'] = pd.Series(res)

# %%
len(df['lemma'])
# Out:
# 21369

# %%
df.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1           8438         42               высшее             0
# 1          1           4025         36              среднее             1
# 2          0           5623         33              Среднее             1
# 3          3           4125         32              среднее             1
# 4          0         340266         53              среднее             1
# 5          0            926         27               высшее             0
# 6          0           2879         43               высшее             0
# 7          0            153         50              СРЕДНЕЕ             1
# 8          2           6930         35               ВЫСШЕЕ             0
# 9          0           2189         41              среднее             1
# 10         2           4171         36               высшее             0
# 11         0            793         40              среднее             1
# 12         0         347978         65              среднее             1
# 13         0           1847         54  неоконченное высшее             2
# 14         0           1845         56               высшее             0
# 15         1            972         26              среднее             1
# 16         0           1720         35              среднее             1
# 17         0           2370         33               высшее             0
# 18         0         400281         53              среднее             1
# 19         0          10039         48              СРЕДНЕЕ             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0    женат / замужем                 0      F   сотрудник     0        253876
# 1    женат / замужем                 0      F   сотрудник     0        112080
# 2    женат / замужем                 0      M   сотрудник     0        145886
# 3    женат / замужем                 0      M   сотрудник     0        267629
# 4   гражданский брак                 1      F   пенсионер     0        158616
# 5   гражданский брак                 1      M   компаньон     0        255764
# 6    женат / замужем                 0      F   компаньон     0        240526
# 7    женат / замужем                 0      M   сотрудник     0        135824
# 8   гражданский брак                 1      F   сотрудник     0         95857
# 9    женат / замужем                 0      M   сотрудник     0        144426
# 10   женат / замужем                 0      M   компаньон     0        113943
# 11   женат / замужем                 0      F   сотрудник     0         77069
# 12  гражданский брак                 1      M   пенсионер     0        131383
# 13   женат / замужем                 0      F   сотрудник     0        130458
# 14  гражданский брак                 1      F   компаньон     1        165128
# 15   женат / замужем                 0      F   сотрудник     0        116821
# 16   женат / замужем                 0      F   сотрудник     0        289203
# 17  гражданский брак                 1      M   сотрудник     0         90411
# 18    вдовец / вдова                 2      F   пенсионер     0         56824
# 19         в разводе                 3      F   сотрудник     0        242831
#
#                                    purpose    category  \
# 0                            покупка жилья    взрослые
# 1                  приобретение автомобиля    взрослые
# 2                            покупка жилья    взрослые
# 3               дополнительное образование    взрослые
# 4                          сыграть свадьбу     пожилые
# 5                            покупка жилья     молодые
# 6                        операции с жильем    взрослые
# 7                              образование     пожилые
# 8                    на проведение свадьбы    взрослые
# 9                  покупка жилья для семьи    взрослые
# 10                    покупка недвижимости    взрослые
# 11       покупка коммерческой недвижимости    взрослые
# 12                         сыграть свадьбу  пенсионеры
# 13                 приобретение автомобиля     пожилые
# 14              покупка жилой недвижимости     пожилые
# 15  строительство собственной недвижимости     молодые
# 16                            недвижимость    взрослые
# 17              строительство недвижимости    взрослые
# 18      на покупку подержанного автомобиля     пожилые
# 19            на покупку своего автомобиля     пожилые
#
#                                      lemma
# 0                            покупка жильё
# 1                  приобретение автомобиль
# 2                            покупка жильё
# 3               дополнительное образование
# 4                          сыграть свадьба
# 5                            покупка жильё
# 6                         операции с жилие
# 7                              образование
# 8                    на проведение свадьба
# 9                  покупка жилья для семья
# 10                    покупка недвижимость
# 11       покупка коммерческой недвижимость
# 12                         сыграть свадьба
# 13                 приобретение автомобиль
# 14              покупка жилой недвижимость
# 15  строительство собственной недвижимость
# 16                            недвижимость
# 17              строительство недвижимость
# 18      на покупку подержанного автомобиль
# 19            на покупку своего автомобиль
