# %% [markdown]
# ## Описание проекта
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ## Инструкция по выполнению
#
# ### Шаг 1. Откройте таблицу и изучите общую информацию о данных
#
# ### Шаг 2. Предобработка данных
# * определите и заполните пропущенные значения:
# * опишите, какие пропущенные значения вы обнаружили;
# * приведите возможные причины появления пропусков в данных;
# * объясните, по какому принципу заполнены пропуски;
# * замените вещественный тип данных на целочисленный:
# * поясните, как выбирали метод для изменения типа данных;
# * удалите дубликаты:
# * поясните, как выбирали метод для поиска и удаления дубликатов в данных;
# * приведите возможные причины появления дубликатов;
# * выделите леммы в значениях столбца с целями получения кредита:
# * опишите, как вы проводили лемматизацию целей кредита;
# * категоризируйте данные: перечислите, какие «словари» вы выделили для этого набора данных, и объясните, почему.
#
# В данных могут встречаться артефакты — значения, которые не отражают действительность. Например, отрицательное количество дней трудового стажа. Для реальных данных — это нормально. Нужно описать возможные причины появления таких данных и обработать их.
#
# ### Шаг 3. Ответьте на вопросы
# * Есть ли зависимость между наличием детей и возвратом кредита в срок?
# * Есть ли зависимость между семейным положением и возвратом кредита в срок?
# * Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# * Как разные цели кредита влияют на его возврат в срок?
#
# Ответы сопроводите интерпретацией — поясните, о чём именно говорит полученный вами результат.
#
# ### Шаг 4. Напишите общий вывод

# %% [markdown]
# #### Описание данных
# 1. `children` — количество детей в семье
# 2. `days_employed` — общий трудовой стаж в днях
# 3. `dob_years` — возраст клиента в годах
# 4.  `education` — уровень образования клиента
# 5.  `education_id` — идентификатор уровня образования
# 6. `family_status` — семейное положение
# 7. `family_status_id` — идентификатор семейного положения
# 8. `gender` — пол клиента
# 9. `income_type` — тип занятости
# 10. `debt` — имел ли задолженность по возврату кредитов
# 11. `total_income` — ежемесячный доход
# 12. `purpose` — цель получения кредита

# %% [markdown]
# ### Шаг 1. Откройте таблицу и изучите общую информацию о данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pymystem3 import Mystem
from collections import Counter

# %%
df = pd.read_csv('/datasets/data.csv')

# %%
df
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1   -8437.673028         42    высшее             0
# 1             1   -4024.803754         36   среднее             1
# 2             0   -5623.422610         33   Среднее             1
# 3             3   -4124.747207         32   среднее             1
# 4             0  340266.072047         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1   -4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1   -2113.346888         38   среднее             1
# 21523         3   -3112.481705         38   среднее             1
# 21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21520  224791.862382             операции с жильем
# 21521  155999.806512          сделка с автомобилем
# 21522   89672.561153                  недвижимость
# 21523  244093.050500  на покупку своего автомобиля
# 21524   82047.418899         на покупку автомобиля
#
# [21525 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Вывод:
#
# В результате знакомства с данными удалось обнаружить, что в двух столбцах имеются пропущенные значения, которые необходимо проработать.

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# Пропущенные значения у нас есть в колонках `days_employed` и `total_income`. Посчитаем сколько их всех и установим процент пропусков.

# %%
df['days_employed'].isna().agg([sum, 'mean'])
# Out:
# sum     2174.000000
# mean       0.100999
# Name: days_employed, dtype: float64

# %%
df['total_income'].isna().agg([sum, 'mean'])
# Out:
# sum     2174.000000
# mean       0.100999
# Name: total_income, dtype: float64

# %% [markdown]
# Как мы видим, количество пропусков вместе с их долей в во всем датафрейме совпадает. Теперь взглянем на датасет только с пропусками и попытаемся найти общую закономерность

# %%
nan = df[df['days_employed'].isna() == True]

# %%
nan.sample(10)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 10013         0            NaN         35    ВЫСШЕЕ             0
# 21281         1            NaN         30    высшее             0
# 2657          0            NaN         53   среднее             1
# 6397          0            NaN         41    высшее             0
# 18043         0            NaN         31    ВЫСШЕЕ             0
# 20187         0            NaN         65   СРЕДНЕЕ             1
# 9951          2            NaN         43   среднее             1
# 9527          0            NaN         36   среднее             1
# 20272         0            NaN         34    высшее             0
# 19885         1            NaN         35   среднее             1
#
#                family_status  family_status_id gender income_type  debt  \
# 10013        женат / замужем                 0      F   компаньон     1
# 21281        женат / замужем                 0      F   сотрудник     0
# 2657               в разводе                 3      F   сотрудник     0
# 6397        гражданский брак                 1      F   сотрудник     0
# 18043  Не женат / не замужем                 4      F   сотрудник     0
# 20187       гражданский брак                 1      F   пенсионер     0
# 9951         женат / замужем                 0      M   сотрудник     0
# 9527         женат / замужем                 0      M   сотрудник     0
# 20272              в разводе                 3      F   сотрудник     0
# 19885        женат / замужем                 0      F   компаньон     0
#
#        total_income                                purpose
# 10013           NaN      покупка коммерческой недвижимости
# 21281           NaN      покупка коммерческой недвижимости
# 2657            NaN  получение дополнительного образования
# 6397            NaN          получение высшего образования
# 18043           NaN                покупка жилья для семьи
# 20187           NaN                        сыграть свадьбу
# 9951            NaN                           ремонт жилью
# 9527            NaN       строительство жилой недвижимости
# 20272           NaN                             автомобиль
# 19885           NaN           на покупку своего автомобиля

# %%
pd.cut(df['dob_years'], 5).value_counts()
# Out:
# (30.0, 45.0]      8504
# (45.0, 60.0]      7057
# (15.0, 30.0]      3723
# (60.0, 75.0]      2140
# (-0.075, 15.0]     101
# Name: dob_years, dtype: int64

# %% [markdown]
# Как мы видим, у нас есть клиенты, у которых в графе возраст есть отрицательные значения и совсем маленькие. Логично, что тут произошла какая-то ошибка при выкачке данных. Поскольку этих данных совсем мало, то их удаление не повлияет на результаты анализа.

# %%
df = df[df['dob_years'] > 15].reset_index()

# %%
df
# Out:
#        index  children  days_employed  dob_years education  education_id  \
# 0          0         1   -8437.673028         42    высшее             0
# 1          1         1   -4024.803754         36   среднее             1
# 2          2         0   -5623.422610         33   Среднее             1
# 3          3         3   -4124.747207         32   среднее             1
# 4          4         0  340266.072047         53   среднее             1
# ...      ...       ...            ...        ...       ...           ...
# 21419  21520         1   -4529.316663         43   среднее             1
# 21420  21521         0  343937.404131         67   среднее             1
# 21421  21522         1   -2113.346888         38   среднее             1
# 21422  21523         3   -3112.481705         38   среднее             1
# 21423  21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21419  гражданский брак                 1      F   компаньон     0
# 21420   женат / замужем                 0      F   пенсионер     0
# 21421  гражданский брак                 1      M   сотрудник     1
# 21422   женат / замужем                 0      M   сотрудник     1
# 21423   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21419  224791.862382             операции с жильем
# 21420  155999.806512          сделка с автомобилем
# 21421   89672.561153                  недвижимость
# 21422  244093.050500  на покупку своего автомобиля
# 21423   82047.418899         на покупку автомобиля
#
# [21424 rows x 13 columns]

# %% [markdown]
# В целом, какой-то общей закономерности пропусков не удалось обнаружить

# %%
def category(age):
    if age <= 30:
        return 'молодые'
    if age > 30 and age <= 45:
        return 'взрослые'
    if age > 45 and age <= 60:
        return 'пожилые'
    return 'пенсионеры'

# %%
df['category'] = df['dob_years'].apply(category)

# %%
df
# Out:
#        index  children  days_employed  dob_years education  education_id  \
# 0          0         1   -8437.673028         42    высшее             0
# 1          1         1   -4024.803754         36   среднее             1
# 2          2         0   -5623.422610         33   Среднее             1
# 3          3         3   -4124.747207         32   среднее             1
# 4          4         0  340266.072047         53   среднее             1
# ...      ...       ...            ...        ...       ...           ...
# 21419  21520         1   -4529.316663         43   среднее             1
# 21420  21521         0  343937.404131         67   среднее             1
# 21421  21522         1   -2113.346888         38   среднее             1
# 21422  21523         3   -3112.481705         38   среднее             1
# 21423  21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21419  гражданский брак                 1      F   компаньон     0
# 21420   женат / замужем                 0      F   пенсионер     0
# 21421  гражданский брак                 1      M   сотрудник     1
# 21422   женат / замужем                 0      M   сотрудник     1
# 21423   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose    category
# 0      253875.639453                 покупка жилья    взрослые
# 1      112080.014102       приобретение автомобиля    взрослые
# 2      145885.952297                 покупка жилья    взрослые
# 3      267628.550329    дополнительное образование    взрослые
# 4      158616.077870               сыграть свадьбу     пожилые
# ...              ...                           ...         ...
# 21419  224791.862382             операции с жильем    взрослые
# 21420  155999.806512          сделка с автомобилем  пенсионеры
# 21421   89672.561153                  недвижимость    взрослые
# 21422  244093.050500  на покупку своего автомобиля    взрослые
# 21423   82047.418899         на покупку автомобиля    взрослые
#
# [21424 rows x 14 columns]

# %% [markdown]
# Посмотрим для каждой возрастной категории среднее значение по гендерным признакам.

# %%
gender_category = df.pivot_table(index = 'category', columns = 'gender', values = 'total_income', aggfunc = 'median')

# %%
gender_category
# Out:
# gender                  F              M            XNA
# category
# взрослые    140315.766455  176410.847993            NaN
# молодые     130187.630873  162513.291433  203905.157261
# пенсионеры  121084.030049  131382.818886            NaN
# пожилые     133412.900442  166523.462873            NaN

# %% [markdown]
# У нас появилось какое-то лишнее значение в графе `gender`, попробуем глянуть сколькор их.

# %%
df['gender'].value_counts()
# Out:
# F      14164
# M       7259
# XNA        1
# Name: gender, dtype: int64

# %% [markdown]
# Можно сразу избавиться от XNA, чтобы это значение не мешало в дальнейшем.

# %%
df = df.query('gender != "XNA"').reset_index()

# %%
df.sample(5)
# Out:
#        level_0  index  children  days_employed  dob_years  education  \
# 9798      9798   9843         0  386183.740055         58    среднее
# 4955      4955   4978         0   -8976.892504         51    среднее
# 890        890    894         0   -1700.034176         53    среднее
# 19683    19684  19780         2   -1299.697206         40     высшее
# 7084      7084   7119         0  353207.809226         60  начальное
#
#        education_id          family_status  family_status_id gender  \
# 9798              1        женат / замужем                 0      F
# 4955              1        женат / замужем                 0      M
# 890               1       гражданский брак                 1      M
# 19683             0              в разводе                 3      F
# 7084              3  Не женат / не замужем                 4      F
#
#       income_type  debt   total_income                           purpose  \
# 9798    пенсионер     0   80616.068650              сделка с автомобилем
# 4955    сотрудник     0   87126.470375   операции со своей недвижимостью
# 890     компаньон     0  183824.326733  строительство жилой недвижимости
# 19683   компаньон     0  110241.616910                       образование
# 7084    пенсионер     0  215864.375057        строительство недвижимости
#
#        category
# 9798    пожилые
# 4955    пожилые
# 890     пожилые
# 19683  взрослые
# 7084    пожилые

# %% [markdown]
# У нас появились лишние столбцы с индексами, которые не несут никакого смысла. Все это можно удлать.

# %%
df = df.drop(['level_0', 'index'], axis = 1)

# %%
woman_adult = gender_category['F'][0]
woman_young = gender_category['F'][1]
woman_pensioner = gender_category['F'][2]
woman_old = gender_category['F'][3]
man_adult = gender_category['M'][0]
man_young = gender_category['M'][1]
man_pensioner = gender_category['M'][2]
man_old = gender_category['M'][3]

# %%
t = df['gender']
k = df['category']
g = []
for i in range(len(k)):
    if t[i] == 'F'and k[i] == 'взрослые':
        g.append(woman_adult)
    if t[i] == 'F'and k[i] == 'молодые':
        g.append(woman_young)
    if t[i] == 'F'and k[i] == 'пенсионеры':
        g.append(woman_pensioner)
    if t[i] == 'F'and k[i] == 'пожилые':
        g.append(woman_old)
    if t[i] == 'M' and k[i] == 'взрослые':
        g.append(man_adult)
    if t[i] == 'M'and k[i] == 'молодые':
        g.append(man_young)
    if t[i] == 'M'and k[i] == 'пенсионеры':
        g.append(man_pensioner)
    if t[i] == 'M'and k[i] == 'пожилые':
        g.append(man_old)

# %%
df['inc_cat'] = pd.Series(g)

# %%
df.sample(10)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 8761          0   -3105.148340         37   среднее             1
# 5026          0  346614.067380         59   среднее             1
# 19217         0  380597.037252         60   Среднее             1
# 20188         2   -4301.422417         48   среднее             1
# 9978          0   -9862.738169         44   среднее             1
# 2761          0   -1453.211233         32    ВЫСШЕЕ             0
# 7724          0  348818.856199         65    высшее             0
# 18003         0  364183.024720         64   среднее             1
# 880           0   -2308.271667         35    высшее             0
# 2597          0            NaN         57   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 8761         женат / замужем                 0      F    сотрудник     0
# 5026        гражданский брак                 1      F    пенсионер     1
# 19217        женат / замужем                 0      F    пенсионер     1
# 20188        женат / замужем                 0      M    сотрудник     0
# 9978         женат / замужем                 0      M    компаньон     0
# 2761         женат / замужем                 0      F    сотрудник     0
# 7724          вдовец / вдова                 2      F    пенсионер     0
# 18003  Не женат / не замужем                 4      F    пенсионер     0
# 880          женат / замужем                 0      M  госслужащий     0
# 2597               в разводе                 3      F    пенсионер     0
#
#         total_income                                 purpose    category  \
# 8761   296570.811912  строительство собственной недвижимости    взрослые
# 5026   123181.625888              строительство недвижимости     пожилые
# 19217  149074.729774              дополнительное образование     пожилые
# 20188  151003.083947                 приобретение автомобиля     пожилые
# 9978   232574.050924                  профильное образование    взрослые
# 2761    87599.203143                                   жилье    взрослые
# 7724    69250.268071  строительство собственной недвижимости  пенсионеры
# 18003   71498.487486                      высшее образование  пенсионеры
# 880    673040.439784            на покупку своего автомобиля    взрослые
# 2597             NaN                 приобретение автомобиля     пожилые
#
#              inc_cat
# 8761   140315.766455
# 5026   133412.900442
# 19217  133412.900442
# 20188  166523.462873
# 9978   176410.847993
# 2761   140315.766455
# 7724   121084.030049
# 18003  121084.030049
# 880    176410.847993
# 2597   133412.900442

# %%
df['total_income'] = df['total_income'].fillna(df['inc_cat'])

# %% [markdown]
# Переведем отрицательные знацения стажа в абсолютные

# %%
df['days_employed'] = abs(df['days_employed'])

# %% [markdown]
# Считаю, что здесь можно воспользоваться такой же логикой замены пропусков какая была при замене `total_income`

# %%
for_days_emp = df.pivot_table(index = 'category', columns = 'gender', values = 'days_employed', aggfunc = 'median')

# %%
for_days_emp
# Out:
# gender                  F              M
# category
# взрослые      1831.729975    1606.607248
# молодые       1097.531171     981.593723
# пенсионеры  358166.492161  347977.727190
# пожилые       4851.384110    2412.732199

# %%
woman_adult_days = for_days_emp['F'][0]
woman_young_days = for_days_emp['F'][1]
woman_pensioner_days = for_days_emp['F'][2]
woman_old_days = for_days_emp['F'][3]
man_adult_days = for_days_emp['M'][0]
man_young_days = for_days_emp['M'][1]
man_pensioner_days = for_days_emp['M'][2]
man_old_days = for_days_emp['M'][3]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21423 entries, 0 to 21422
# Data columns (total 14 columns):
# children            21423 non-null int64
# days_employed       19259 non-null float64
# dob_years           21423 non-null int64
# education           21423 non-null object
# education_id        21423 non-null int64
# family_status       21423 non-null object
# family_status_id    21423 non-null int64
# gender              21423 non-null object
# income_type         21423 non-null object
# debt                21423 non-null int64
# total_income        21423 non-null float64
# purpose             21423 non-null object
# category            21423 non-null object
# inc_cat             21423 non-null float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 2.3+ MB

# %%
c = df['gender']
v = df['category']
h = []
for i in range(len(v)):
    if c[i] == 'F'and v[i] == 'взрослые':
        h.append(woman_adult_days)
    if c[i] == 'F'and v[i] == 'молодые':
        h.append(woman_young_days)
    if c[i] == 'F'and v[i] == 'пенсионеры':
        h.append(woman_pensioner_days)
    if c[i] == 'F'and v[i] == 'пожилые':
        h.append(woman_old_days)
    if c[i] == 'M' and v[i] == 'взрослые':
        h.append(man_adult_days)
    if c[i] == 'M'and v[i] == 'молодые':
        h.append(man_young_days)
    if c[i] == 'M'and v[i] == 'пенсионеры':
        h.append(man_pensioner_days)
    if c[i] == 'M'and v[i] == 'пожилые':
        h.append(man_old_days)

# %%
len(h)
# Out:
# 21423

# %%
df['days'] = pd.Series(h)
df.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0     926.185831         27    высшее             0
# 6         0    2879.202052         43    высшее             0
# 7         0     152.779569         50   СРЕДНЕЕ             1
# 8         2    6929.865299         35    ВЫСШЕЕ             0
# 9         0    2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
# 5  гражданский брак                 1      M   компаньон     0  255763.565419
# 6   женат / замужем                 0      F   компаньон     0  240525.971920
# 7   женат / замужем                 0      M   сотрудник     0  135823.934197
# 8  гражданский брак                 1      F   сотрудник     0   95856.832424
# 9   женат / замужем                 0      M   сотрудник     0  144425.938277
#
#                       purpose  category        inc_cat         days
# 0               покупка жилья  взрослые  140315.766455  1831.729975
# 1     приобретение автомобиля  взрослые  140315.766455  1831.729975
# 2               покупка жилья  взрослые  176410.847993  1606.607248
# 3  дополнительное образование  взрослые  176410.847993  1606.607248
# 4             сыграть свадьбу   пожилые  133412.900442  4851.384110
# 5               покупка жилья   молодые  162513.291433   981.593723
# 6           операции с жильем  взрослые  140315.766455  1831.729975
# 7                 образование   пожилые  166523.462873  2412.732199
# 8       на проведение свадьбы  взрослые  140315.766455  1831.729975
# 9     покупка жилья для семьи  взрослые  176410.847993  1606.607248

# %%
df['days_employed'] = df['days_employed'].fillna(df['days'])

# %%
df.sample(10)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 9858          0    1412.149795         26    ВЫСШЕЕ             0
# 3268          1  371280.006979         51   среднее             1
# 1439          0    1980.262882         29   среднее             1
# 4266          1    2307.778406         52   среднее             1
# 1231          1    1115.784625         30   среднее             1
# 20115         2    6924.906648         56   Среднее             1
# 6308          1     216.786303         42    высшее             0
# 20640         0     605.186692         60   среднее             1
# 13673         0    2930.866014         63   среднее             1
# 12592         0  342434.334622         56   среднее             1
#
#                family_status  family_status_id gender income_type  debt  \
# 9858   Не женат / не замужем                 4      F   сотрудник     0
# 3268         женат / замужем                 0      F   пенсионер     0
# 1439         женат / замужем                 0      M   сотрудник     0
# 4266         женат / замужем                 0      M   компаньон     0
# 1231   Не женат / не замужем                 4      F   сотрудник     0
# 20115  Не женат / не замужем                 4      M   сотрудник     0
# 6308         женат / замужем                 0      F   компаньон     0
# 20640        женат / замужем                 0      F   компаньон     0
# 13673        женат / замужем                 0      F   компаньон     0
# 12592         вдовец / вдова                 2      F   пенсионер     0
#
#         total_income                            purpose    category  \
# 9858   116362.018151    операции со своей недвижимостью     молодые
# 3268   149148.038069      получение высшего образования     пожилые
# 1439   117590.107671            приобретение автомобиля     молодые
# 4266   159623.172987      получение высшего образования     пожилые
# 1231    97484.340407            покупка жилья для семьи     молодые
# 20115  135240.965916  покупка коммерческой недвижимости     пожилые
# 6308   118906.691207         покупка жилой недвижимости    взрослые
# 20640  197845.721171         покупка жилой недвижимости     пожилые
# 13673  211507.768746         покупка жилой недвижимости  пенсионеры
# 12592   67557.043107    операции со своей недвижимостью     пожилые
#
#              inc_cat           days
# 9858   130187.630873    1097.531171
# 3268   133412.900442    4851.384110
# 1439   162513.291433     981.593723
# 4266   166523.462873    2412.732199
# 1231   130187.630873    1097.531171
# 20115  166523.462873    2412.732199
# 6308   140315.766455    1831.729975
# 20640  133412.900442    4851.384110
# 13673  121084.030049  358166.492161
# 12592  133412.900442    4851.384110

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21423 entries, 0 to 21422
# Data columns (total 15 columns):
# children            21423 non-null int64
# days_employed       21423 non-null float64
# dob_years           21423 non-null int64
# education           21423 non-null object
# education_id        21423 non-null int64
# family_status       21423 non-null object
# family_status_id    21423 non-null int64
# gender              21423 non-null object
# income_type         21423 non-null object
# debt                21423 non-null int64
# total_income        21423 non-null float64
# purpose             21423 non-null object
# category            21423 non-null object
# inc_cat             21423 non-null float64
# days                21423 non-null float64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 2.5+ MB

# %%
df.duplicated().sum()
# Out:
# 54

# %%
df = df.drop_duplicates(keep='first')

# %%
df.sample(5)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 302           2    7381.422129         36   среднее             1
# 20715         0    4851.384110         59    высшее             0
# 258           1    1710.140334         29   среднее             1
# 14985         2     902.945416         30   среднее             1
# 13738         0    2376.645119         54   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 302           в разводе                 3      F   сотрудник     1
# 20715   женат / замужем                 0      F   пенсионер     0
# 258    гражданский брак                 1      F   компаньон     0
# 14985   женат / замужем                 0      F   сотрудник     0
# 13738   женат / замужем                 0      M   сотрудник     0
#
#         total_income                                purpose  category  \
# 302     45033.203067                           недвижимость  взрослые
# 20715  133412.900442                             автомобили   пожилые
# 258    286533.860192                покупка жилья для семьи   молодые
# 14985   77845.966978  получение дополнительного образования   молодые
# 13738  131766.407948  получение дополнительного образования   пожилые
#
#              inc_cat         days
# 302    140315.766455  1831.729975
# 20715  133412.900442  4851.384110
# 258    130187.630873  1097.531171
# 14985  130187.630873  1097.531171
# 13738  166523.462873  2412.732199

# %% [markdown]
# Уберем лишние столбцы, которые нам больше не понадобятся.

# %%
df = df.drop(['inc_cat', 'days'], axis = 1)

# %% [markdown]
# Теперь округлим и заменим тип данных в столбцах `days_employed` и `total_income` для дальнейшего удоства.

# %%
df['days_employed'] = round(df['days_employed'], 0)
df['days_employed'] = df['days_employed'].astype(int)
df['total_income'] = round(df['total_income'], 0)
df['total_income'] = df['total_income'].astype(int)

# %%
df.dtypes
# Out:
# children             int64
# days_employed        int64
# dob_years            int64
# education           object
# education_id         int64
# family_status       object
# family_status_id     int64
# gender              object
# income_type         object
# debt                 int64
# total_income         int64
# purpose             object
# category            object
# dtype: object

# %%
df
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1           8438         42    высшее             0
# 1             1           4025         36   среднее             1
# 2             0           5623         33   Среднее             1
# 3             3           4125         32   среднее             1
# 4             0         340266         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21418         1           4529         43   среднее             1
# 21419         0         343937         67   среднее             1
# 21420         1           2113         38   среднее             1
# 21421         3           3112         38   среднее             1
# 21422         2           1985         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21418  гражданский брак                 1      F   компаньон     0
# 21419   женат / замужем                 0      F   пенсионер     0
# 21420  гражданский брак                 1      M   сотрудник     1
# 21421   женат / замужем                 0      M   сотрудник     1
# 21422   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose    category
# 0            253876                 покупка жилья    взрослые
# 1            112080       приобретение автомобиля    взрослые
# 2            145886                 покупка жилья    взрослые
# 3            267629    дополнительное образование    взрослые
# 4            158616               сыграть свадьбу     пожилые
# ...             ...                           ...         ...
# 21418        224792             операции с жильем    взрослые
# 21419        156000          сделка с автомобилем  пенсионеры
# 21420         89673                  недвижимость    взрослые
# 21421        244093  на покупку своего автомобиля    взрослые
# 21422         82047         на покупку автомобиля    взрослые
#
# [21369 rows x 13 columns]

# %% [markdown]
# Для дальнейшего анализа нам необходимо определить леммы, чтобы мы смогли отфильтровать клиентов по причинам займа.

# %%
unique = df['purpose'].unique()

# %%
from pymystem3 import Mystem
m = Mystem()
from collections import Counter

# %%
key = df['purpose']
lem = []
for i in key:
    result = ''.join(m.lemmatize(i)).strip()
    lem.append(result)

df1 = pd.DataFrame(data=lem, columns=['lemmas'])

# %%
df1
# Out:
#                            lemmas
# 0                   покупка жилье
# 1         приобретение автомобиль
# 2                   покупка жилье
# 3      дополнительный образование
# 4                 сыграть свадьба
# ...                           ...
# 21364            операция с жилье
# 21365         сделка с автомобиль
# 21366                недвижимость
# 21367  на покупка свой автомобиль
# 21368       на покупка автомобиль
#
# [21369 rows x 1 columns]

# %%
len(df1)
# Out:
# 21369

# %%
df1['lemmas'].isna().sum()
# Out:
# 0

# %% [markdown]
# При помощи лемматизации мы определили все значения целей кредитования и сохранили их в отдельном Датафрейме, чтобы все корректно поделить на категории.

# %% [markdown]
# Теперь сделаем категоризацию данных на основе имеющегося Датафрейма после лемматизации.

# %%
def uniq(text):
    m.lemmatize(text)
    if ('жилье' in text or 'недвижимость' in text):
        return 'недвижимость'
    if ('автомобиль' in text):
        return 'авто'
    if ('образование' in text):
        return 'образование'
    if ('свадьба' in text):
        return 'свадьба'
    return 'прочее'
    
#добавляем в Датафрейм корректные категории целей выдачи кредита для дальнейшего анализа.    
df['for_category'] = df1['lemmas'].apply(uniq)

df.sample(10)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 1112          1            998         31   среднее             1
# 3054          1           3020         48   среднее             1
# 10880         0            479         33   среднее             1
# 19406         1         398716         54    Высшее             0
# 9105          0           4812         59    высшее             0
# 8711          0           2413         58   среднее             1
# 278           1           1913         44   среднее             1
# 20193         0            715         26   среднее             1
# 13599         0           2449         42   среднее             1
# 6266          0            278         34    высшее             0
#
#                family_status  family_status_id gender income_type  debt  \
# 1112        гражданский брак                 1      F   сотрудник     0
# 3054         женат / замужем                 0      M   сотрудник     0
# 10880        женат / замужем                 0      M   сотрудник     0
# 19406        женат / замужем                 0      M   пенсионер     0
# 9105        гражданский брак                 1      F   сотрудник     0
# 8711         женат / замужем                 0      M   сотрудник     0
# 278          женат / замужем                 0      M   компаньон     0
# 20193  Не женат / не замужем                 4      M   компаньон     0
# 13599              в разводе                 3      F   сотрудник     0
# 6266        гражданский брак                 1      M   компаньон     0
#
#        total_income                            purpose  category  for_category
# 1112         227852                         автомобиль  взрослые          авто
# 3054         222613               покупка своего жилья   пожилые          авто
# 10880        120327                         автомобили  взрослые          авто
# 19406        553314   строительство жилой недвижимости   пожилые  недвижимость
# 9105         333825                    сыграть свадьбу   пожилые  недвижимость
# 8711         166523         строительство недвижимости   пожилые          авто
# 278          207375                       ремонт жилью  взрослые  недвижимость
# 20193        230016   строительство жилой недвижимости   молодые  недвижимость
# 13599        266017            покупка жилья для семьи  взрослые  недвижимость
# 6266         203879  покупка коммерческой недвижимости  взрослые   образование

# %% [markdown]
# При помощи Лемматизации мы смогли классифицировать клиентов на категории.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21369 entries, 0 to 21422
# Data columns (total 14 columns):
# children            21369 non-null int64
# days_employed       21369 non-null int64
# dob_years           21369 non-null int64
# education           21369 non-null object
# education_id        21369 non-null int64
# family_status       21369 non-null object
# family_status_id    21369 non-null int64
# gender              21369 non-null object
# income_type         21369 non-null object
# debt                21369 non-null int64
# total_income        21369 non-null int64
# purpose             21369 non-null object
# category            21369 non-null object
# for_category        21315 non-null object
# dtypes: int64(7), object(7)
# memory usage: 2.4+ MB

# %%
df[df['for_category'].isna() == True]
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 21369         0           6241         59              среднее             1
# 21370         2           2769         39               высшее             0
# 21371         0           9945         48              среднее             1
# 21372         1            395         33               высшее             0
# 21373         0         365213         52              среднее             1
# 21374         0           2540         52               высшее             0
# 21375         0           1628         54              среднее             1
# 21376         1            921         28               Высшее             0
# 21377         0            686         26              среднее             1
# 21378         0           8799         45               высшее             0
# 21379         0            830         30  неоконченное высшее             2
# 21380         1            865         25              среднее             1
# 21381         2           2917         38            начальное             3
# 21382         3            969         35              среднее             1
# 21383         0         363996         59               высшее             0
# 21384         0           1614         36              СРЕДНЕЕ             1
# 21385         0           2377         30              СРЕДНЕЕ             1
# 21386         0            355         35               высшее             0
# 21387         2           2413         47              Среднее             1
# 21388         2           1867         32              среднее             1
# 21389        20            174         27              среднее             1
# 21390         0           1619         54              среднее             1
# 21391         1           1215         38              среднее             1
# 21392         0            960         39              среднее             1
# 21393         1           4851         50              среднее             1
# 21394         1            760         31              среднее             1
# 21395         0           4851         48               ВЫСШЕЕ             0
# 21396         1           1331         32              среднее             1
# 21397         0           9929         57              среднее             1
# 21398         0            578         26  неоконченное высшее             2
# 21399         0         334343         57              среднее             1
# 21400         1           1832         42              среднее             1
# 21401         0           3097         58              среднее             1
# 21402         0         355236         68              среднее             1
# 21403         0         338905         53              среднее             1
# 21404         1           1556         33               ВЫСШЕЕ             0
# 21405         1             80         32              среднее             1
# 21406         0         386498         62              среднее             1
# 21407         0         362161         59               высшее             0
# 21408         2           1098         28              среднее             1
# 21409         0            613         29               высшее             0
# 21410         0            165         26               высшее             0
# 21411         0           1166         35              среднее             1
# 21412         0            280         27  неоконченное высшее             2
# 21413         1            468         28              среднее             1
# 21414         0            914         42               высшее             0
# 21415         0            405         42               высшее             0
# 21416         0         373996         59              СРЕДНЕЕ             1
# 21417         1           2351         37       ученая степень             4
# 21418         1           4529         43              среднее             1
# 21419         0         343937         67              среднее             1
# 21420         1           2113         38              среднее             1
# 21421         3           3112         38              среднее             1
# 21422         2           1985         40              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 21369        женат / замужем                 0      F    сотрудник     0
# 21370        женат / замужем                 0      F    компаньон     0
# 21371        женат / замужем                 0      F    сотрудник     0
# 21372        женат / замужем                 0      F    сотрудник     0
# 21373        женат / замужем                 0      F    пенсионер     1
# 21374        женат / замужем                 0      M    компаньон     0
# 21375       гражданский брак                 1      F    сотрудник     0
# 21376        женат / замужем                 0      F    сотрудник     0
# 21377        женат / замужем                 0      M    сотрудник     0
# 21378  Не женат / не замужем                 4      F    сотрудник     0
# 21379       гражданский брак                 1      M    сотрудник     0
# 21380        женат / замужем                 0      F    компаньон     0
# 21381       гражданский брак                 1      F    сотрудник     1
# 21382        женат / замужем                 0      M    сотрудник     0
# 21383        женат / замужем                 0      F    пенсионер     0
# 21384        женат / замужем                 0      F    сотрудник     1
# 21385       гражданский брак                 1      F    сотрудник     0
# 21386  Не женат / не замужем                 4      F    компаньон     0
# 21387        женат / замужем                 0      M    компаньон     0
# 21388        женат / замужем                 0      F    сотрудник     0
# 21389        женат / замужем                 0      F    сотрудник     0
# 21390        женат / замужем                 0      M    компаньон     0
# 21391        женат / замужем                 0      F    сотрудник     0
# 21392       гражданский брак                 1      M    компаньон     1
# 21393       гражданский брак                 1      F    сотрудник     0
# 21394        женат / замужем                 0      F    сотрудник     0
# 21395        женат / замужем                 0      F    компаньон     0
# 21396       гражданский брак                 1      M    сотрудник     0
# 21397       гражданский брак                 1      M    компаньон     0
# 21398  Не женат / не замужем                 4      M    компаньон     0
# 21399        женат / замужем                 0      F    пенсионер     0
# 21400        женат / замужем                 0      F    сотрудник     0
# 21401        женат / замужем                 0      F    сотрудник     0
# 21402        женат / замужем                 0      F    пенсионер     0
# 21403       гражданский брак                 1      M    пенсионер     0
# 21404       гражданский брак                 1      F    сотрудник     0
# 21405       гражданский брак                 1      F  госслужащий     0
# 21406        женат / замужем                 0      M    пенсионер     0
# 21407        женат / замужем                 0      M    пенсионер     0
# 21408        женат / замужем                 0      F    сотрудник     0
# 21409       гражданский брак                 1      F    сотрудник     1
# 21410  Не женат / не замужем                 4      M    компаньон     0
# 21411        женат / замужем                 0      F    сотрудник     0
# 21412  Не женат / не замужем                 4      M    компаньон     0
# 21413        женат / замужем                 0      F    сотрудник     1
# 21414        женат / замужем                 0      F    компаньон     0
# 21415       гражданский брак                 1      F    компаньон     0
# 21416        женат / замужем                 0      F    пенсионер     0
# 21417              в разводе                 3      M    сотрудник     0
# 21418       гражданский брак                 1      F    компаньон     0
# 21419        женат / замужем                 0      F    пенсионер     0
# 21420       гражданский брак                 1      M    сотрудник     1
# 21421        женат / замужем                 0      M    сотрудник     1
# 21422        женат / замужем                 0      F    сотрудник     0
#
#        total_income                                purpose    category  \
# 21369        244123                                  жилье     пожилые
# 21370        362691                             автомобили    взрослые
# 21371        200224  операции с коммерческой недвижимостью     пожилые
# 21372        282902                   сделка с автомобилем    взрослые
# 21373         48239                        свой автомобиль     пожилые
# 21374        527453        операции со своей недвижимостью     пожилые
# 21375         71734                  на проведение свадьбы     пожилые
# 21376        181186                        свой автомобиль     молодые
# 21377        171504                покупка жилья для сдачи     молодые
# 21378        146945                           ремонт жилью    взрослые
# 21379        440471                  на покупку автомобиля     молодые
# 21380         94065                        свой автомобиль     молодые
# 21381         77418               операции с недвижимостью    взрослые
# 21382         95667                                  жилье    взрослые
# 21383        267001     на покупку подержанного автомобиля     пожилые
# 21384         80764                             автомобиль    взрослые
# 21385         87835                           недвижимость     молодые
# 21386        128897                           недвижимость    взрослые
# 21387        166523                   сделка с автомобилем     пожилые
# 21388         34768  операции с коммерческой недвижимостью    взрослые
# 21389        155521     на покупку подержанного автомобиля     молодые
# 21390        295234             покупка жилой недвижимости     пожилые
# 21391        147503                покупка жилья для семьи    взрослые
# 21392        176370             дополнительное образование    взрослые
# 21393        133413                                свадьба     пожилые
# 21394        119393                  на покупку автомобиля    взрослые
# 21395        133413             строительство недвижимости     пожилые
# 21396        240768                        сыграть свадьбу    взрослые
# 21397        157553                                свадьба     пожилые
# 21398         77813  операции с коммерческой недвижимостью     молодые
# 21399         86232                                  жилье     пожилые
# 21400        140316       строительство жилой недвижимости    взрослые
# 21401        264251                  заняться образованием     пожилые
# 21402         80566             дополнительное образование  пенсионеры
# 21403         75440                        сыграть свадьбу     пожилые
# 21404        145542                                свадьба    взрослые
# 21405         98180       сделка с подержанным автомобилем    взрослые
# 21406         72639                           недвижимость  пенсионеры
# 21407         73029               операции с недвижимостью     пожилые
# 21408        130188                приобретение автомобиля     молодые
# 21409        140068                покупка жилья для сдачи     молодые
# 21410        147301  получение дополнительного образования     молодые
# 21411        250986                          покупка жилья    взрослые
# 21412        355988             строительство недвижимости     молодые
# 21413        109486                  заняться образованием     молодые
# 21414        322808                   покупка своего жилья    взрослые
# 21415        178060           на покупку своего автомобиля    взрослые
# 21416        153865                   сделка с автомобилем     пожилые
# 21417        115949      покупка коммерческой недвижимости    взрослые
# 21418        224792                      операции с жильем    взрослые
# 21419        156000                   сделка с автомобилем  пенсионеры
# 21420         89673                           недвижимость    взрослые
# 21421        244093           на покупку своего автомобиля    взрослые
# 21422         82047                  на покупку автомобиля    взрослые
#
#       for_category
# 21369          NaN
# 21370          NaN
# 21371          NaN
# 21372          NaN
# 21373          NaN
# 21374          NaN
# 21375          NaN
# 21376          NaN
# 21377          NaN
# 21378          NaN
# 21379          NaN
# 21380          NaN
# 21381          NaN
# 21382          NaN
# 21383          NaN
# 21384          NaN
# 21385          NaN
# 21386          NaN
# 21387          NaN
# 21388          NaN
# 21389          NaN
# 21390          NaN
# 21391          NaN
# 21392          NaN
# 21393          NaN
# 21394          NaN
# 21395          NaN
# 21396          NaN
# 21397          NaN
# 21398          NaN
# 21399          NaN
# 21400          NaN
# 21401          NaN
# 21402          NaN
# 21403          NaN
# 21404          NaN
# 21405          NaN
# 21406          NaN
# 21407          NaN
# 21408          NaN
# 21409          NaN
# 21410          NaN
# 21411          NaN
# 21412          NaN
# 21413          NaN
# 21414          NaN
# 21415          NaN
# 21416          NaN
# 21417          NaN
# 21418          NaN
# 21419          NaN
# 21420          NaN
# 21421          NaN
# 21422          NaN

# %% [markdown]
# При помощи метода Квантиль определим 5 категорий уровню дохода для классификации клиентов.

# %%
spisok = []
for i in [0.2, 0.4, 0.6, 0.8, 1]:
    key = df['total_income'].quantile(i)
    spisok.append(key)
    print('Доля дохода при', i*100, "%", df['total_income'].quantile(i))
    
money = pd.Series(spisok)
# Out:
# Доля дохода при 20.0 % 98580.8
# Доля дохода при 40.0 % 131970.2
# Доля дохода при 60.0 % 162513.0
# Доля дохода при 80.0 % 214489.20000000004
# Доля дохода при 100 % 2265604.0

# %%
df['']

# %%
#Cоздав функцию мы определим всех клиентов на категории по доходам.

def level_income(income):
    if income <= money[0]:
        return 'очень низкий доход'
    if income <= money[1]:
        return 'низкий доход'
    if income <= money[2]:
        return 'средний доход'
    if income <= money[3]:
        return 'высокий доход'
    return 'очень высокий доход'

#Добавляем в датафрейм категории по доходам
    
df['group_income'] = df['total_income'].apply(level_income)

# %%
df['for_category'].isna().sum()
# Out:
# 54
