# %% [markdown]
# ## Описание проекта
#
# Исследуем данные сервиса Яндекс.Недвижимость. В данном случае — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность. По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Инструкция по выполнению проекта
#
# ### Шаг 1. Откройте файл с данными и изучите общую информацию
# * [Путь к файлу: /datasets/real_estate_data.csv. Скачать датасет](#step1)
#
# ### Шаг 2. Предобработка данных
# * [Определите и изучите пропущенные значения:](#step2)
#   - для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов —      скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В    этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать;
#   - заполните пропуски, где это уместно. Опишите, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали  значения;
#   - укажите причины, которые могли привести к пропускам в данных.
# * [Приведите данные к нужным типам:](#step3)
#   - поясните, в каких столбцах нужно изменить тип данных и почему.
#
# ### Шаг 3. Посчитайте и добавьте в таблицу:
# * [Цену квадратного метра;](#step4)
# * [День недели, месяц и год публикации объявления;](#step5)
# * [Этаж квартиры; варианты — первый, последний, другой;](#step6)
# * [Соотношение жилой и общей площади, а также отношение площади кухни к общей.](#step7)
#
# ### Шаг 4. Проведите исследовательский анализ данных и выполните инструкции:
# * [Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.](#step8)
# * [Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?](#step9)
# * [Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.](#step10)
# * [Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.](#step11)
# * [Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.](#step12)
# * [Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.](#step13)
# * [Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?](#step14)
#
# ### Шаг 5. Напишите общий вывод
#
# * [Написать итоговый вывод](#step15)
#
# #### Описание данных
#
# 1. `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# 2. `balcony` — число балконов
# 3. `ceiling_height` — высота потолков (м)
# 4. `cityCenters_nearest` — расстояние до центра города (м)
# 5. `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# 6. `first_day_exposition` — дата публикации
# 7. `floor` — этаж
# 8. `floors_total` — floors_total — всего этажей в доме
# 10. `kitchen_area` — площадь кухни в квадратных метрах (м²)
# 11. `last_price` — цена на момент снятия с публикации
# 12. `living_area` — жилая площадь в квадратных метрах(м²)
# 13. `locality_name` — название населённого пункта
# 14. `open_plan` — свободная планировка (булев тип)
# 15. `parks_around3000` — число парков в радиусе 3 км
# 16. `parks_nearest` — расстояние до ближайшего парка (м)
# 17. `ponds_around3000` — число водоёмов в радиусе 3 км
# 18. `ponds_nearest` — расстояние до ближайшего водоёма (м)
# 19. `rooms` — число комнат
# 20. `studio` — квартира-студия (булев тип)
# 21. `total_area` — площадь квартиры в квадратных метрах (м²)
# 22. `total_images` — число фотографий квартиры в объявлении
# 23. `is_apartment` — апартаменты (булев тип)
#
# Пояснение: апартаменты — это нежилые помещения, не относящиеся к жилому фонду, но имеющие необходимые условия для проживания.

# %% [markdown]
# ## Шаг №1. Знакомство с данными<a id="step1"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %%
df = pd.read_csv('real_estate_data.csv', sep = "\t")

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# ### Вывод:
#
# Мы ознакомились с полученными данными и сразу заметно, что у нас очень много пропусков + придется изменять типы данных для дальнейшего анализа.

# %% [markdown]
# ## Шаг №2. Предобработка данных

# %%
display(df)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# Посмотрим на количество пропусков во всем Датафрейме.<a id="step2"></a>

# %%
print('Количество пропусков в процентах')
(100 * round(df.isna().mean(), 2))
# Out:
# Количество пропусков в процентах
# total_images             0.0
# last_price               0.0
# total_area               0.0
# first_day_exposition     0.0
# rooms                    0.0
# ceiling_height          39.0
# floors_total             0.0
# living_area              8.0
# floor                    0.0
# is_apartment            88.0
# studio                   0.0
# open_plan                0.0
# kitchen_area            10.0
# balcony                 49.0
# locality_name            0.0
# airports_nearest        23.0
# cityCenters_nearest     23.0
# parks_around3000        23.0
# parks_nearest           66.0
# ponds_around3000        23.0
# ponds_nearest           62.0
# days_exposition         13.0
# dtype: float64

# %% [markdown]
# Как мы видим, пропусков достаточно много и начнем разбираться с каждой колонкой по отдельности. Сразу можно сказать, что скорее всего колонки где доля пропусков по 23%, имеют общую закономерность.

# %% [markdown]
# Начнем с высоты пололков и посомтрим на их количество, и средние параметры с медианой.

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.50      3515
# 2.60      1646
# 2.70      1574
# 3.00      1112
# 2.80       993
#           ...
# 27.50        1
# 5.00         1
# 3.59         1
# 4.80         1
# 100.00       1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
print('Медиана -', (df['ceiling_height'].median()))
print('Среднее -', round(df['ceiling_height'].mean(), 2))
# Out:
# Медиана - 2.65
# Среднее - 2.77

# %% [markdown]
# Как мы видим, cреднее и медиана находятся где-то между 2.7. Если обращать внимание на строительные нормы на 2021 год, то как раз высота потолков 2.7 является железным стандартом.
#
# Мне кажется что можно прикинуть высоту потолков в зависимости от этажности и от этого произвести замену.

# %%
def howlevel(num):
    if num >= 1 and num <= 5:
        return 'малоэтажки'
    elif num > 5 and num < 10:
        return 'многоэтажки'
    else:
        return 'высокоэтажки'

df['new_floor'] = df['floors_total'].apply(howlevel)

# %%
k = []
for i in ['малоэтажки', 'многоэтажки', 'высокоэтажки']:
    result = df[df['new_floor'] == i]['ceiling_height'].median()
    k.append(result)

level = pd.DataFrame(data = k, columns = ['level'])

# %%
level
# Out:
#    level
# 0    2.6
# 1    2.6
# 2    2.7

# %% [markdown]
# Теперь произведем замену пропусков в зависимости от этажности

# %%
columns = ['малоэтажки', 'многоэтажки', 'высокоэтажки']
for i in range(len(columns)):
    df.loc[df['new_floor'] == columns[i],'ceiling_height'] = df.loc[df['new_floor'] == columns[i],'ceiling_height'].fillna(level['level'][i])

# %% [markdown]
# Теперь посмотрим, все ли удалось изменить.

# %%
df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# Посмотрим на пропуски `living_area` и произведем замену по такому же принципу. С одной стороны, мы можем избавиться от пропусков, так как их в данном случае всего 8%, но считаю, что правильнее их будет заменить, так как в целом в датасете их много, и удаление этих 8% может потянуть за собой часть нормальных данных.

# %%
p = []
for i in ['малоэтажки', 'многоэтажки', 'высокоэтажки']:
    result = (df[df['new_floor'] == i]['living_area'].median())
    p.append(result)

area = pd.DataFrame(data = p, columns = ['area'])

# %%
area
# Out:
#     area
# 0  30.75
# 1  32.00
# 2  27.40

# %%
columns = ['малоэтажки', 'многоэтажки', 'высокоэтажки']
for i in range(len(columns)):
    df.loc[df['new_floor'] == columns[i],'living_area'] = df.loc[df['new_floor'] == columns[i],'living_area'].fillna(level['level'][i])

# %% [markdown]
# `is_apartment` - а вот здесь пропусков 88 % и мы их как раз трогать не будем и оставим на месте, тем более, эта колонка не сильно требуется для анализа

# %% [markdown]
# А вот в `kitchen_area` используем привычную для этого проекта логику замены пропусков.

# %%
f = []
for i in ['малоэтажки', 'многоэтажки', 'высокоэтажки']:
    result = (df[df['new_floor'] == i]['kitchen_area'].median())
    f.append(result)

kitch = pd.DataFrame(data = f, columns = ['kit_area'])

# %%
kitch.head(3)
# Out:
#    kit_area
# 0       7.6
# 1       8.3
# 2      10.8

# %%
columns = ['малоэтажки', 'многоэтажки', 'высокоэтажки']
for i in range(len(columns)):
    df.loc[df['new_floor'] == columns[i],'kitchen_area'] = df.loc[df['new_floor'] == columns[i],'kitchen_area'].fillna(level['level'][i])

# %% [markdown]
# `balcony` - имеет почти 50% пропусков. Скорее всего, пропуски говорят о том, что в этих квартирах могло не оказаться балконов и пользователи поставили 0. Здесь прость подставим 0.

# %%
df['balcony'] = df['balcony'].fillna(0)

# %% [markdown]
# Мы обнаружли, что существют квартиры у которых в графе количество комнат - 0.
#
# Посмотрим на эти значения.

# %%
df.sort_values('rooms').head(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 9412              5   2100000.0       16.00  2017-12-10T00:00:00      0
# 8886             10   2450000.0       15.50  2018-08-22T00:00:00      0
# 18132             6   4800000.0       32.50  2019-04-09T00:00:00      0
# 20002             8   2700000.0       28.00  2017-11-10T00:00:00      0
# 21425             4   2700000.0       25.70  2018-01-01T00:00:00      0
# 12229            12   6200000.0       32.40  2018-02-22T00:00:00      0
# 3019             18   2100000.0       24.00  2017-11-10T00:00:00      0
# 2532              5   3500000.0       27.10  2018-02-01T00:00:00      0
# 22047             0   3400000.0       24.00  2017-05-31T00:00:00      0
# 2727              4   3670000.0       26.49  2018-07-26T00:00:00      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 9412              2.6           6.0         13.0      1          NaN   False
# ...

# %%
df.query('rooms == "0"').groupby('rooms')['living_area'].agg('mean')
# Out:
# rooms
# 0    17.714924
# Name: living_area, dtype: float64

# %% [markdown]
# Как мы заметили, квартиры "Без комнат" имеют среднюю жилую площадь в районе до 18 метров, а общая варьируется значениями до 35 метров.
# Получается, что везде где стоят 0 в 'Rooms', мы имеем дело с однокомнатной квартирой или квартирой-студией. Поэтому заменим значение 0 на 1.

# %%
df.loc[df['rooms'] == 0] = df.loc[df['rooms'] == 0].replace(to_replace = 0, value = 1)

# %% [markdown]
# Теперь посмотрим на пропуски по удаленности прудов и парков. Здесь, как мне кажется, если есть пропуски, то это может нам сказать о том, что парков и прудов в радиусе 3 КМ нет. Произведем замену.

# %%
df['parks_around3000'] = df['parks_around3000'].fillna(0)
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)

# %% [markdown]
# Считаю, что как-то правильно заменить оставшиеся колонки нет смысла. Замена не даст должного результата + то что мы пытаемся заменить не требуется для Анализа.

# %% [markdown]
# Как мне кажется, пропуски появились из-за того, что не все пользователи заполняли данные. Возможно, в некоторых пунктах что-то плохо выгрузилось. Необходимо передать информацию об этом Дата-инженеру.

# %% [markdown]
# <a id="step3"></a>  Теперь заменим типы данных для дальнейшего удобства.
# Что касается замены, то я считаю, нет смысла менять ничего, кроме даты публикации, цены, числа балконов, поскольку все остальные колонки пригодны для дальнейшего анализа.

# %%
df = df[np.isfinite(df['floors_total'])]

df['floors_total'] = df['floors_total'].astype(int)
df['last_price'] = df['last_price'].astype(int)
df['balcony'] = df['balcony'].astype(int)
df['is_apartment'] = df['is_apartment'].astype(bool)
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# ### Вывод:
#
# Несмотря на пропуски, самые важные и необходимые для анализа данные мы смогли восстановить. Некоторые пропуски по типу высоты потолков, появились вероятно из-за того, что люди при публикации не знают таких параметров или не заполняли их, так как потолки более менее стандартные. Что касается расстояний до аэропорта, до центра и ближайшего парка, то скорее всего, люди не указывали эти параметры, так как их имущество находится очень далеко и смысла заполянть эти значения нет. Все данные готовы к дальнейшему анализу.

# %% [markdown]
# ## Шаг №3. Посчитать и добавить в таблицу

# %% [markdown]
# <a id="step4"></a>  Посчитаем и добавим в таблицу цену квадратного метра:

# %%
df['price_of_metr'] = (df['last_price'] / df['total_area']).astype(int)

# %% [markdown]
# <a id="step5"></a>  Посчитаем и добавим в таблицу: день недели, месяц и год публикации объявления

# %%
df['day_exp'] = df['first_day_exposition'].dt.weekday
df['month_exp'] = df['first_day_exposition'].dt.month
df['year_exp'] = df['first_day_exposition'].dt.year

# %% [markdown]
# <a id="step6"></a>  Посчитаем и добавим в таблицу: этаж квартиры (варианты — первый, последний, другой)

# %%
def floor_category(row):
    if row[8] == 1:
        return 'первый'
    if row[8] == row[6]:
        return 'последний'
    return 'другой'
        
df['floor_category'] = df.apply(floor_category, axis = 1)

# %% [markdown]
# <a id="step7"></a>  Посчитаем и добавим в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
df['living_to_total'] = round(df['living_area'] / df['total_area'], 2)
df['kitchen_to_total'] = round(df['kitchen_area'] / df['total_area'], 2)

# %% [markdown]
# Теперь посмотрим что получилось

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# ## Шаг №4. Исследовательский анализ данных

# %% [markdown]
# * Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.
# * Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
# * Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.
# * Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.
# * Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.
# * Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.
# * Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# <a id="step8"></a>  Посмотрим на параметры площади, цены, числа комнат и высоты потолков.

# %%
hist_columns = df.loc[:, ['total_area','last_price', 'ceiling_height', 'price_of_metr', 'rooms']]
for column in hist_columns:
   
    qr = df[column].quantile(.75) - df[column].quantile(.25) #межквартальный размах
   
    mini = df[column].min() # минимальный диапозон
    qmin = df[column].quantile(.25) - qr * 3
    if qmin < mini:
        qmin = mini
    else:
        qmin = qmin
   
    maxi = df[column].max() # максимальный диапазон
    qmax = df[column].quantile(.75) + qr * 3
    if qmax > maxi:
        qmax = maxi
    else:
        qmax = qmax
       
    hist_columns.hist(column, bins = 20, range = ((qmin), (qmax))) #строит гистограммы в нужном диапазоне

# %% [markdown]
# Длинные хвосты имеют графики с ценой и площадью. Для дальнейшего анализа оставим только нормальные распределения, а хвосты отбросим. Жилая площадь в основном при нормальном распределении от 20 до 140 метров. Цена до 10 млн, как показал график является самым приемлимым вариантом для данной выборки.
#
# Что касается количества комнат, то в среднем в объявлениях до 4-х. Все остальное является редким и выбивающимся значением.

# %% [markdown]
# <a id="step9"></a>  Теперь посмотрим дни до продажи

# %%
print('Медиана дней до продажи:', df['days_exposition'].median())
print(df['days_exposition'].describe())
# Out:
# Медиана дней до продажи: 95.0
# count    20441.000000
# mean       180.884839
# std        219.685543
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# По стандартному отклонению от среднего, мы понимаем, что выбросы есть, но них немного. Построим гистограму дней продажи и введем лимит до 200 дней. Если будем строить без лимита, то на графике будет сложно что-либо разобрать.

# %%
df['days_exposition'].hist(bins = 100, range = (1, 200))

# %% [markdown]
# Судя по имеющейся гистограмме, мы можем считать, что быстрая продажа делается в среднем от 5 до 100 дней. Все что выше 650 дней, уже говорит о слишком долгой продаже квартиры.
#
# Мы обнаружили выбивающиеся значенися около 45 и 60 дней и именно на них, как оказалось, на сервисе происходит автоматическая деактивация объявлений. Считаю, что эти значения можно убрать из датафрейма.

# %% [markdown]
# <a id="step10"></a>  Уберем редкие и выбивающиеся значения из датафрейма на основе Гистограмм, полученных ранее.
# Из особенностей: Мы обнаружли огромные значения в стоимости квартир.

# %%
without_trash = df.query('days_exposition != 45 and days_exposition != 60 and days_exposition < 650 and last_price < 25000000 and 20000 < price_of_metr < 200000 and 15 < total_area < 140 and rooms < 6')

# %%
without_trash = without_trash.reset_index()

# %%
without_trash.head(10)
# Out:
#    index  total_images  last_price  total_area first_day_exposition  rooms  \
# 0      1             7     3350000       40.40           2018-12-04      1
# 1      2            10     5196000       56.00           2015-08-20      2
# 2      4             2    10000000      100.00           2018-06-19      2
# 3      5            10     2890000       30.40           2018-09-10      1
# 4      6             6     3700000       37.30           2017-11-02      1
# 5      8            20     2900000       33.16           2018-05-23      1
# 6      9            18     5400000       61.00           2017-02-26      3
# 7     10             5     5050000       39.60           2017-11-16      1
# 8     11             9     3300000       44.00           2018-08-27      2
# 9     12            10     3890000       54.00           2016-06-30      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Выведем взаимосвязь между различными интересующими нас параметрами и посчитаем корреляцию. <a id="step11"></a>

# %%
without_trash.corr()['last_price']
# Out:
# index                 -0.002956
# total_images           0.159754
# last_price             1.000000
# total_area             0.779527
# rooms                  0.494340
# ceiling_height         0.091541
# floors_total           0.132320
# living_area            0.555659
# floor                  0.104895
# is_apartment          -0.017690
# studio                -0.060407
# open_plan             -0.043541
# kitchen_area           0.500536
# balcony                0.071801
# airports_nearest      -0.031692
# cityCenters_nearest   -0.346029
# parks_around3000       0.255841
# parks_nearest          0.067829
# ponds_around3000       0.288797
# ponds_nearest         -0.087637
# days_exposition        0.088481
# price_of_metr          0.642793
# day_exp               -0.014757
# month_exp              0.007914
# year_exp              -0.023446
# living_to_total        0.023990
# kitchen_to_total      -0.089138
# Name: last_price, dtype: float64

# %%
for_corr = without_trash.pivot_table(index = 'last_price', values = ['price_of_metr','rooms','cityCenters_nearest'])
pd.plotting.scatter_matrix(for_corr, figsize=(9, 9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018DEF1C2FC8>,
# ...
#       dtype=object)

# %% [markdown]
# Как мы видим из графика, тесная связь есть наблюдается у недорогих квартир. Более того, недорогие квартиры имеют примерно одинаковую цену за квадратный метр. Если смотреть дальше, то там уже и разброс идет сильнее. Вероятно это связано с тем, что в дорогих квартирах плюсом к цене идет дорогостоящий ремонт, который может неплохо так повлиять на конечную стоимость квадратного метра. В недорогих квартирах все необорот, ремонт в основном простой.
#
# На графике о комнатах видно, что тесно связано отношение цены c однокомнатными квартирами. Особенно стоимость от 2 до 4 миллионов. В двухкомнатных самая тесная связь у квартир стоимостью около 4 миллионов, а если смотреть на трехкомнатные квартиры, то небольшая связь наблюдается у квартир по 5 миллионов. Если посмотреть на все три зависимости, то складывается ощущение, что у них есть общая взаимосвязь, которая теряется с переходом на уровень выше. Это наводит на мысль, что чем дешевле квартира, тем у нее все более стандартно и шаблонно.

# %% [markdown]
# Найдем взаимосвязь от дней, месяцев и года:

# %%
columns = ['day_exp', 'month_exp', 'year_exp']
for i in columns:
    without_trash.pivot_table(index = i, values = 'last_price').plot(grid = True)

# %% [markdown]
# * Что касается зависимости от дня публикации, то на графике видно, что если квартиры выставляют ближе к выходным, то они дешевле. В воскресенье дела с ценам хуже всего.
# * Ситуация с месяцами достаточно интересна. Дороже всего выставляются с июня по сентябрь. Видимо, это самый благоприятный период для осуществления переезда.
# * Как показывает Линейный график зависимости от года публикации, что лучше всего квартиры продавались в 2014 году. Видимо, после кризиса 2014 упал спрос и квартиры чуть подешевели.

# %%
without_trash.pivot_table(index='cityCenters_nearest', values='last_price', aggfunc='mean').plot(figsize = (14,6))

# %% [markdown]
# Данный график демонстрирует нам, что опять же квартры стоимостью от 3 до 12 миллионов имеют самую высокую концентрацию, и особенно ближе к центру. Это подкрепляет теорию, что у недорогих квартир есть общая закономерность ценообразования. После 35 км от центра мы уже не видим дорогих квартир, а значит, что это в основном пошла перефирия.

# %% [markdown]
# Найдем 10 населённых пунктов с наибольшим числом объявлений.<a id="step12"></a>

# %%
top10 = without_trash['locality_name'].value_counts().sort_values(ascending=False).head(10).index

best_city = without_trash.query('locality_name in @top10').pivot_table(index='locality_name', values='price_of_metr', aggfunc='mean')

best_city.sort_values('price_of_metr')
# Out:
#                    price_of_metr
# locality_name
# Выборг              57101.225131
# Всеволожск          66679.841270
# Гатчина             68618.116667
# Колпино             74649.140411
# посёлок Шушары      77720.696335
# посёлок Мурино      85771.088477
# посёлок Парголово   89510.501779
# деревня Кудрово     92624.545113
# Пушкин             100645.150735
# Санкт-Петербург    106199.356124

# %% [markdown]
# Как и ожидалось, самая дорогая недвижимость находится в Северной столице. Дешевле всего жилье находится в Выборге, и скорее всего это связано с удаленностью от Санкт-Петербурга. Если рассматривать стоимость от нижнего значения к верхнему, то картина складывается так - чем ближе населенный пункт к Питеру, тем стоимость выше. Причем единственным местом, которое выбивается из этой логики - это город Пушкин. Вероятно, высокая стоиомсть жилья обусловлена близостью к Аэропорту и наличию Екатеринингоского дворца. Шушары, также расположены близко к аэропорту и Санкт-Петербургу, однако имеет статус поселка, что влияет на цену.

# %%
without_trash['nearest_km'] = without_trash['cityCenters_nearest'] / 1000

# %% [markdown]
# Поскольку у нас остались пропуски в колонке Расстояние до центра, то мы специально заменим их 0, для перевода столбца к целым числам. Для дальнейшено рассчета все нулевые значения устраним.

# %%
without_trash['nearest_km'] = without_trash['nearest_km'].fillna(9999)

# %%
without_trash['nearest_km'] = (round(without_trash['nearest_km'], 0)).astype(int)

# %%
spb = without_trash.query('locality_name == "Санкт-Петербург" and nearest_km != 9999').reset_index()
spb = spb.drop(['level_0', 'index'], axis = 1)

# %%
spb
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                10     5196000       56.00           2015-08-20      2
# 1                 2    10000000      100.00           2018-06-19      2
# 2                18     5400000       61.00           2017-02-26      3
# 3                 5     5050000       39.60           2017-11-16      1
# 4                16     4650000       39.00           2017-11-18      1
# ...             ...         ...         ...                  ...    ...
# 11755            19     9200000      101.00           2019-04-01      3
# 11756            13     3550000       35.30           2018-02-28      1
# 11757             3     5500000       52.00           2018-07-19      2
# 11758            11     9470000       72.90           2016-10-13      2
# 11759            13    11475000       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
spb['mean_price_for_km'] =  round(spb['last_price'] / spb['nearest_km'], 0)

# %%
spb
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                10     5196000       56.00           2015-08-20      2
# 1                 2    10000000      100.00           2018-06-19      2
# 2                18     5400000       61.00           2017-02-26      3
# 3                 5     5050000       39.60           2017-11-16      1
# 4                16     4650000       39.00           2017-11-18      1
# ...             ...         ...         ...                  ...    ...
# 11755            19     9200000      101.00           2019-04-01      3
# 11756            13     3550000       35.30           2018-02-28      1
# 11757             3     5500000       52.00           2018-07-19      2
# 11758            11     9470000       72.90           2016-10-13      2
# 11759            13    11475000       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Посчитаем среднюю цену для каждого километра от центра

# %%
result_km = spb.pivot_table(index = 'nearest_km', values = 'last_price', aggfunc = 'mean')
result_km['last_price'] = (round(result_km['last_price'], 1)).astype(int)
result_km.head(10)
# Out:
#             last_price
# nearest_km
# 0              8886666
# 1             10197252
# 2              8860345
# 3              7985304
# 4              8460623
# 5              8879534
# 6              8061699
# 7              7359623
# 8              7547956
# 9              6165609

# %%
spb.pivot_table(index = 'nearest_km', values = 'last_price', aggfunc = 'mean').plot(grid = True)

# %% [markdown]
# Есть очень странный выброс с показателем более 26 км. Постараемся определить откуда он взялся

# %%
spb.query('nearest_km > 25 and last_price > 8000000')
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 329            13    14350000        74.0           2017-11-28      2
#
#      ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 329            3.13             5         30.0      3          True   False
#
#      open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 329      False          25.0        0  Санкт-Петербург           23888.0
#
#      cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 329              27313.0               1.0         1496.0               0.0
#
#      ponds_nearest  days_exposition   new_floor  price_of_metr  day_exp  \
# 329            NaN            128.0  малоэтажки         193918        1
#
#      month_exp  year_exp floor_category  living_to_total  kitchen_to_total  \
# 329         11      2017         другой             0.41              0.34
#
#      nearest_km  mean_price_for_km
# ...

# %% [markdown]
# Скорее всего, скачок был связан с квартирой за 14,5 миллионов. С виду она ничем не выделяется - 74 квадратных метра, 2 комнаты, 3 этаж пятиэтажного дома. Создается ощущение, что либо там золотой ремонт, либо кто-то ошибся с ценой при публикации.

# %%
pd.set_option('display.max_columns', None)

# %%
spb
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                10     5196000       56.00           2015-08-20      2
# 1                 2    10000000      100.00           2018-06-19      2
# 2                18     5400000       61.00           2017-02-26      3
# 3                 5     5050000       39.60           2017-11-16      1
# 4                16     4650000       39.00           2017-11-18      1
# ...             ...         ...         ...                  ...    ...
# 11755            19     9200000      101.00           2019-04-01      3
# 11756            13     3550000       35.30           2018-02-28      1
# 11757             3     5500000       52.00           2018-07-19      2
# 11758            11     9470000       72.90           2016-10-13      2
# 11759            13    11475000       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Проанализируем весь город целиком по следующим параметрами: площадь, цена, число комнат, высота потолков.<a id="step13"></a>

# %%
spb['total_area'].hist(grid = True)

# %%
spb['last_price'].hist()

# %%
spb['rooms'].hist()

# %%
spb['ceiling_height'].hist(bins = 20)

# %% [markdown]
# Типичная квартира в Питербурге выглядит так: в основном это 1-2 комнатная квартира площадью в среднем от 30 до 80 квадратных метров и стоимостью от 3 до 8 миллионов. Высота потолков стандартная.

# %% [markdown]
# Теперь посмотрим распределение цены относительно центра и установим его границы

# %%
spb.pivot_table(index='cityCenters_nearest',values='last_price',aggfunc='mean').plot(figsize = (14,6))

# %% [markdown]
# Как мы видимо по графику, чем ближе квартира к центру, тем больше становится рассеивание. Можно сделать вывод, что если расстояние до центра менее 7 км, то это сильно сказывается на стоимости жилья и квадратным метр сильно колеблится. Посе 7 км стоимость заметно снижается.

# %%
center_spb_grouped = spb.query('cityCenters_nearest < 7000')

# %% [markdown]
# <a id="step14"></a>  Теперь проанализируем весь Центр Санкт-Петербурга по следующим параметрами: площадь, цена, число комнат, высота потолков

# %%
center_spb_grouped['total_area'].hist(facecolor='red', bins = 10)

# %%
center_spb_grouped['last_price'].hist(facecolor='red')

# %%
center_spb_grouped['rooms'].hist(facecolor='red')

# %%
center_spb_grouped['ceiling_height'].hist(facecolor='red', bins = 20)

# %% [markdown]
# Квартира в центре Питера выгляди так: В основном это 2-3 комнатные квартиры. Средняя стоиомость составляет от 4 до 11 миллионов рублей. Высота потолков стандартная, но имеются исключения, скорее всего из-за дореволюционной застройки в центре, с высокими потолками. Средняя площадь от 40 до 110 метров.
#
# Если сравнивать квартиры в центре Питера с теми, что за центром, то мы видим, что за центром преймущественно 1-2 комнатные квартиры, а вот в центре 2-3 комнатные. Видно по графику, что смоимость квартир в центре заметно выше. Количество значений с нестандартной высотой потолков в центре выше, и это говорит о том, что это могут быть дореволюционные квартиры, что тоже влияет на стоимость.

# %% [markdown]
# ## Шаг №5. Итоговый вывод <a id="step15"></a>

# %% [markdown]
# Мы сделали сравнительный анализ по продаже квартир. В результате, пришли к выводу - Чем дальше квартира находится от Северной столицы, тем стоимость ее дешевле. Влияет на стоимость и ну цену удаленность от аэропорта. Если населенный пункт находится ближе к аэропорту чем город, но он имеет статус(Поселок, деревня), то недвижимость там будет дешевле, чем у города, который ближе к нему. Публикации квартир чаще всего происходили в 2014 году, и видимо это связано с кризимом, так как далее их публиковали реже. Плюс чаще всего их выставляют летом, видимо для удобства переезда. Квартиры выставляемые с понедельника по четверг, как правило, дороже, чем с пятницы по воскресенье. Самыми популярными квартирами являются 2 комнатные. Успешной считается продажа, если она длилась до 650 дней. Чаще всего квартиры продовались сроком до 100 дней.
#
# Из наблюдений заметил, что у некоторых однушек общая площадь почти равна площади жилой, что говорит о том, что в продаже скорее всего Коммунальная квартира или студия.
#
# Центром города считается область менее 7 км от самого центра. Распределение в самом Санкт-Петербурге тоже интересное. За центром в продаже в основно 1-2 комнатные квартира, а вот в самом центре продаются преймущественно 2-3 комнатные. Эта же тенденция и применима и к площади. Есть предположение, что за центром квартиры продаются в основном в новом фонде, поскольку высота потолков стандартная, плюс больше продается однушек. Как известно, застройщики сейчас стараются строить на окраинах наиболее доступное жилье, которое имеет недорогую цену и небольшую квадратуру. Если говорить о ценах, то квартиры за центром Питера более 10 миллионов это уже какая-то редкость. В центре наоборот, там разброс большой и сами квартиры стоят дороже.
